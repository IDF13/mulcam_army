# %%
from __future__ import print_function

import json
import time

import re
import requests

# %%
headers = 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko'
# youtube comment scrape
results =[]
comment_list = []
youtube_id ='2HyspUw5L0U'
url = f'https://www.youtube.com/watch?v={youtube_id}'

response = requests.get(f'https://www.youtube.com/watch?v={youtube_id}')
print(url)
print()
print(response)
SORT_BY_POPULAR = 0
SORT_BY_RECENT = 1

YT_CFG_RE = r'ytcfg\.set\s*\(\s*({.+?})\s*\)\s*;'
YT_INITIAL_DATA_RE = r'(?:window\s*\[\s*["\']ytInitialData["\']\s*\]|ytInitialData)\s*=\s*({.+?})\s*;\s*(?:var\s+meta|</script|\n)'
# Out:
# https://www.youtube.com/watch?v=2HyspUw5L0U
#
# <Response [200]>

# %%
def regex_search(text,pattern,group=1,default=None):
    match = re.search(pattern,text)
    if match:
        match = match.group(group)
    else:
        default
    return match

# %%
def ajax_request(session, endpoint, ytcfg, retries=5, sleep=20):
    url = 'https://www.youtube.com'+endpoint['commandMetadata']['webCommandMetadata']['apiUrl']

    data = {
        'context': ytcfg['INNERTUBE_CONTEXT']
        ,'continuation': endpoint['continuationCommand']['token']
    }
    print(data)
    for _ in range(retries):
        response = session.post(
            url
            ,params = {'key':ytcfg['INNERTUBE_API_KEY']}
            ,json = data
        )
        if response.status_code == 200:
            return response.json()
        if response.status_code in [403,413]:
            return {}
        else:
            time.sleep(time)

# %%
def download_comments(sort_by=SORT_BY_RECENT, sleep=.1):
    session = requests.Session()
    session.headers['User-Agent'] = headers

    response = session.get(url)

    if 'uxe=' in response.request.url:
        session.cookies.set('CONSENT','YES+cb',domain='.youtube.com')
        response = session.get(url)

    html = response.text
    ytcfg = json.loads(regex_search(html, YT_CFG_RE, default=''))
    if not ytcfg:
        return # unable to extract configuration

    data = json.loads(regex_search(html,YT_INITIAL_DATA_RE,default=''))

    section = next(search_dict(data,'itemSectionRenderer'),None)
    renderer = next(search_dict(section,'continuationItemRenderer'),None) if section else None
    if not renderer:
        return

    needs_sorting = sort_by != SORT_BY_RECENT
    continuations = [renderer['continuationEndpoint']]
    while continuations:
        continuation = continuations.pop()
        response = ajax_request(session,continuation,ytcfg)

        if not response:
            break
        if list(search_dict(response,'externalErrorMessage')):
            raise RuntimeError('Error returned from server: ' + 
            next(search_dict(response, 'externalErrorMessage')))
        if needs_sorting:
            sort_menu = next(search_dict(response,'sortFilterSubMenuRenderer'), {}).get('subMenuItems',[])
            if sort_by < len(sort_menu):
                continuations = [sort_menu[sort_by]['serviceEndpoint']]
                needs_sorting = False
                continue
            raise RuntimeError('Failed to set sorting')

        actions = list(search_dict(response,'reloadContinuationItemsCommand'))+list(search_dict(response,'appendContinuationItemsAction'))

        for action in actions:
            for item in action.get('continuationItems',[]):
                if action['targetId'] == 'comments-section':
                    continuations[:0] = [ep for ep in search_dict(item,'continuationEndpoint')]
                if action['targetId'].startswith('comment-replies-item') and 'continuationItemRenderer' in item:
                    # 'show more replies' 버튼
                    pass
                    # continuation.append(next(search_dict(item,'buttonRenderer'))['command'])

        for comment in reversed(list(search_dict(response,'commentRenderer'))):
            yield {
                '댓글': ''.join([c['text'] for c in comment['contentText'].get('runs',[])])
                ,'좋아요': comment.get('voteCount',{}).get('simpleText','0')
            }
            
            # return ''.join([c['댓글'] for c in comment['contentText'].get('runs',[])])

        time.sleep(sleep)

# %%
def search_dict(partial, search_key):
    stack = [partial]
    while stack:
        current_item = stack.pop()
        # dictionary
        if isinstance(current_item, dict): 
            for k,v in current_item.items():
                if k == search_key:
                    yield v
                else:
                    stack.append(v)
        # list
        elif isinstance(current_item, list):
            for v in current_item:
                stack.append(v)

# %%
for item in download_comments():
    print(item)

# \n 제거하려면 .strip()
# Out:
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyJSIRIgsySHlzcFV3NUwwVTAAeAJCEGNvbW1lbnRzLXNlY3Rpb24%3D'}
# {'댓글': "the lights during Karina's dance were so cool! Also their live vocals <3", '좋아요': '142'}
# {'댓글': 'Giselle looks so gorgeous with black hair💗✨\n\n\n\n\n\n\nI choose the right bias.', '좋아요': '245'}
# {'댓글': 'Winter’s visual is not joke 😲😲', '좋아요': '109'}
# {'댓글': 'got chills when watching this live stage in 5am. They are incredible.', '좋아요': '15'}
# {'댓글': 'Thier all so beautiful.....Karina,Giselle,Winter,NingNing....saranghe', '좋아요': '37'}
# {'댓글': 'Ningning yüksek notasi mükemmeldi ve Mikrofon acikk', '좋아요': '28'}
# {'댓글': 'Ningning vocals 😍😌', '좋아요': '38'}
# {'댓글': 'Woah this is bomb this group is wrecking my sanity æ❤', '좋아요': '0'}
# {'댓글': 'I just found out that Kwangya is on the map🤣', '좋아요': '63'}
# {'댓글': "i never understand when haters said they didn't singing live. This is the evident", '좋아요': '30'}
# {'댓글': 'AESPA QUEENS!💙', '좋아요': '17'}
# {'댓글': 'Seeing karina makes me happy', '좋아요': '5'}
# {'댓글': 'Giselle 😍😍😍', '좋아요': '56'}
# {'댓글': 'AESPAAAAA👑💜', '좋아요': '30'}
# {'댓글': "Lol the beginning English text hurt my head a little, could've been worded a little better by the company lmao - no hate, just saying a massive company could've checked their grammar😂", '좋아요': '27'}
# {'댓글': 'Вау,почему я не посмотрела это раньше?', '좋아요': '1'}
# {'댓글': '예뻐 ㅜ', '좋아요': '1'}
# {'댓글': 'la voz mas hermosa del mundo es de ning ning', '좋아요': '7'}
# {'댓글': "Karina's intro just a chef kiss.", '좋아요': '1'}
# {'댓글': 'NEW GEN QUEENS 💖', '좋아요': '1'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3lWR2hacmthQzJoZ2FWR3NoNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3lWR2hacmthQzJoZ2FWR3NoNEFhQUJBZw%3D%3D'}
# {'댓글': 'They are not singing live, when it is the part of Whinter it is much more noticeable', '좋아요': '6'}
# {'댓글': 'They are not singing live', '좋아요': '5'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3c5dEpxTHV0ZmV3bTJuTWZGNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3c5dEpxTHV0ZmV3bTJuTWZGNEFhQUJBZw%3D%3D'}
# {'댓글': 'shes my bias too and i dont regret it <3', '좋아요': '8'}
# {'댓글': 'I know right', '좋아요': '4'}
# {'댓글': "she's just a living ae for me", '좋아요': '3'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3k0djJaRmxaMXNWVTBfcTZSNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3k0djJaRmxaMXNWVTBfcTZSNEFhQUJBZw%3D%3D'}
# {'댓글': 'They are not singing live, when it is the part of Whinter it is much more noticeable', '좋아요': '7'}
# {'댓글': 'It’s obvious they’re not singing live...', '좋아요': '8'}
# {'댓글': 'Their vocal is pre-recorded, so this performance is half lip sync + half pre-recorded vocal, you can see different in mic, aespa are using "Band-Aid" mic, the mic is always provided by broadcasting company as it\'s cheap, and it\'s quality is very low. if sing live, singer will use black microphone or big black microphone, you can check IZ*ONE Fiesta Inkigayo 20200301 ~ IZ*ONE Fiesta performance at Inkigayo 20200301, half lip sync + half live ~', '좋아요': '0'}
# {'댓글': '\xa0@Snow Yuki Yap\xa0 just watched it. I don’t think that had any of them singing live either. If they were, the live vocals were turned down a LOT. And this is coming from someone who loves IZ*ONE.', '좋아요': '2'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3lRTGxTSU5MMnh3M2lYNTNsNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3lRTGxTSU5MMnh3M2lYNTNsNEFhQUJBZw%3D%3D'}
# {'댓글': 'they are middle sized company 😂', '좋아요': '0'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': '...'}
# {'댓글': 'the intro is just so MUAH', '좋아요': '9'}
# {'댓글': 'The camera work is so poor.... The background looks amazing, they look amazing! But the camera is making it look so dull... Bruh...', '좋아요': '35'}
# {'댓글': 'Ning Ning😍😍😍', '좋아요': '52'}
# {'댓글': 'The camera works failed, It failed to catch the main point of the choreo..', '좋아요': '46'}
# {'댓글': 'the location 😂', '좋아요': '304'}
# {'댓글': 'Ningning❤', '좋아요': '19'}
# {'댓글': 'هاذو خير من مامبا 🙂', '좋아요': '0'}
# {'댓글': 'Oh my god....karina🦋', '좋아요': '1'}
# {'댓글': '카리나 눈나 나랑 사귀자제발', '좋아요': '2'}
# {'댓글': 'Beautiful 💘💘💘💘💘', '좋아요': '4'}
# {'댓글': 'The outfit of Karina so beautiful', '좋아요': '0'}
# {'댓글': '❤️😍', '좋아요': '12'}
# {'댓글': 'Karina is so perfect', '좋아요': '9'}
# {'댓글': 'Winter😍😍😍', '좋아요': '27'}
# {'댓글': 'GISELLE NO BANGSSS', '좋아요': '2'}
# {'댓글': 'Location ~ KWANGYA, undetected from google maps', '좋아요': '3'}
# {'댓글': '💜', '좋아요': '5'}
# {'댓글': 'Karina 😍😍😍', '좋아요': '25'}
# {'댓글': 'Ningning❤', '좋아요': '3'}
# {'댓글': 'LOVE Karina！', '좋아요': '1'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3duMVZwY09Xdno1OEdmSjJONEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3duMVZwY09Xdno1OEdmSjJONEFhQUJBZw%3D%3D'}
# {'댓글': "That's what i noticed too.", '좋아요': '3'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3hOYldwQTNqc1IwU20wY3NwNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3hOYldwQTNqc1IwU20wY3NwNEFhQUJBZw%3D%3D'}
# {'댓글': 'Yeah. Without the camera works, the choreo looks so dull', '좋아요': '3'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3hkMW1ZNXFYQVNUYkcxVGs5NEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3hkMW1ZNXFYQVNUYkcxVGs5NEFhQUJBZw%3D%3D'}
# {'댓글': "what's wrong with it?", '좋아요': '4'}
# {'댓글': 'nothing. it made me happy actually^^ calm down pls 😭', '좋아요': '13'}
# {'댓글': '\xa0@cchlattetae\xa0 the location said: Kwangya =)))', '좋아요': '22'}
# {'댓글': 'oh sorry, I thought you meant it in a bad way lmao', '좋아요': '5'}
# {'댓글': '\u200b\xa0@cchlattetae\xa0 no worries lol', '좋아요': '5'}
# {'댓글': 'LMAO,😂😂 Kwangya😂😂', '좋아요': '5'}
# {'댓글': '😆 it took me like 1 whole minute to understand haha', '좋아요': '5'}
# {'댓글': 'What’s wrong with the location🧐🤨', '좋아요': '0'}
# {'댓글': '\xa0@Kayla Kayla\xa0  teori', '좋아요': '0'}
# {'댓글': 'I still don’t get it but thx', '좋아요': '0'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3l0aXZEb3duT2RQVVpqcURGNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3l0aXZEb3duT2RQVVpqcURGNEFhQUJBZw%3D%3D'}
# {'댓글': 'You are Right 👍👍👍', '좋아요': '2'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': '...'}
# {'댓글': 'is there a video of aespa at the dream concert?', '좋아요': '12'}
# {'댓글': 'I love aespa anyeong', '좋아요': '1'}
# {'댓글': 'Their clothes tend to not  match their music and concept. They need to stop.', '좋아요': '1'}
# {'댓글': "i am not saying they are similar or what but aespa really give Blackpink's vibe. i know Aespa os Aespa and Blackpink is Blackpink but i dont know 4 girls with top visual but not really rely on that because each one is soo talented. also i like to point out how Blackpink and Aespa have similar height which make them in one group looks so nice. ahh what i am saying is both are soo good.", '좋아요': '6'}
# {'댓글': 'K OSMO, WANGYA', '좋아요': '4'}
# {'댓글': '여기 에스파 팬들 많겠지마는; 나도 여자라도 예뻐서 들어온거지만ㅋ 댄스 솔로 시작부분은 좀 임팩트가 약했다봄 ㅋㅋ만약 현아나 청아가 저기서 췄다면? 어땠을지ㅋ 생각해보면 느껴짐', '좋아요': '0'}
# {'댓글': "Where's the crowd", '좋아요': '0'}
# {'댓글': 'Menos onda le ponen jsjsjs\nAsí serían las nuevas blackpink? Xd', '좋아요': '0'}
# {'댓글': 'Phép thuật winxx', '좋아요': '0'}
# {'댓글': 'Stupid cameraman..', '좋아요': '2'}
# {'댓글': 'Karinaaaa 😍😍😍', '좋아요': '16'}
# {'댓글': 'Might the stylist not understand their model shapes and the stage background. The designs do not work well on the girls except Karina. Her body is in the best shape and white dress helps her a lot, other members arenot that lucky. Too colorful background, dancers in black and Aespa cant take the spotlight. Hope the stylist makes it better next time', '좋아요': '3'}
# {'댓글': 'They are not singing live, when it is the part of Whinter it is much more noticeable', '좋아요': '9'}
# {'댓글': 'WINX CLUB', '좋아요': '1'}
# {'댓글': 'Wineer is secret number not aespa flop', '좋아요': '2'}
# {'댓글': 'Does anyone have a presentation where they think they are singing live? Because of all I can not find any.', '좋아요': '1'}
# {'댓글': 'Karina', '좋아요': '1'}
# {'댓글': 'Off mic', '좋아요': '0'}
# {'댓글': 'Aespa flop', '좋아요': '2'}
# {'댓글': 'Flip', '좋아요': '1'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3hmYTNsWlNfVGx0RW92ZXZkNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3hmYTNsWlNfVGx0RW92ZXZkNEFhQUJBZw%3D%3D'}
# {'댓글': 'Not for me. Aespa having more creativity from their concept.. they give so much effort for concept...', '좋아요': '15'}
# {'댓글': '\xa0@Khusus YT\xa0 yeah thts what fourth gen gotta do btw. U know sm style and yg are different. Yg never playing with that concept theory and sm yeah. Since exo thou. So yeah their concept is different but both group slay with their own identity', '좋아요': '3'}
# {'댓글': "Both groups are great. But they don't have the same vibe, concept-wise and vocal-wise. \n\nBlackpink's badass concepts give off the obvious, somewhat chaotic vibe reminiscent of their seniors Big Bang and 2ne1. Aespa has more versatile concepts, and even their badass concepts exude seamless elegance (another classic SM trademark no matter the concept is for any SM artist/group). \n\nAespa is a vocal powerhouse. (Consistent great quality of singing is personally my top priority when stanning a kpop artist or group.)\n\nEven the rapping, Blackpink has the classic strong, in-your-face quality while Aespa's rapping is more of the subdued type, but the flow is remarkable nonetheless. \n\nBlackpink is already a senior group while Aespa is still a rookie group so comparing them is somewhat unfair lol but yeah, they are both amazing.", '좋아요': '12'}
# {'댓글': 'Hope they will be popular like bp', '좋아요': '2'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3lxMG14SE44bks2NzRCaG50NEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3lxMG14SE44bks2NzRCaG50NEFhQUJBZw%3D%3D'}
# {'댓글': "It's so irrelevant tho", '좋아요': '2'}
# {'댓글': '\xa0@expelled from mars\xa0 yea but its weird that they’re trynna make them sound live💀', '좋아요': '0'}
# {'댓글': "\xa0@britt\xa0 bruh, it's pre-recorded what do expect?", '좋아요': '0'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3pfb0dvVWkxMVB3aS1RRUNwNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3pfb0dvVWkxMVB3aS1RRUNwNEFhQUJBZw%3D%3D'}
# {'댓글': 'Barbie?', '좋아요': '0'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3pNZkZkbVh2UENEMWlIWDFoNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3pNZkZkbVh2UENEMWlIWDFoNEFhQUJBZw%3D%3D'}
# {'댓글': 'did sn get number one on melon ?', '좋아요': '9'}
# {'댓글': 'Did SN get a good on digital more than aespa ? Its no obviously, you cant win if you just handle by voting .', '좋아요': '1'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3k0S0N2YzVMSDZGY3NvUWlsNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3k0S0N2YzVMSDZGY3NvUWlsNEFhQUJBZw%3D%3D'}
# {'댓글': 'Flop tu vieja', '좋아요': '0'}
# {'댓글': '\xa0@skz world domination\xa0 flop.', '좋아요': '0'}
# {'댓글': '\xa0@ZigDug\xa0 decís flop a las best rokies JANDJSNSJJSJS STUPID', '좋아요': '0'}
# {'댓글': '\xa0@skz world domination\xa0 AESPA flop ew', '좋아요': '0'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': '...%3D'}
# {'댓글': 'Why boy bands better then girls', '좋아요': '2'}
# {'context': {'client': {'hl': 'ko', 'gl': 'KR', 'remoteHost': '119.196.53.160', 'deviceMake': '', 'deviceModel': '', 'visitorData': 'Cgt5bWJxUU5NVWlPVSinpa6JBg%3D%3D', 'userAgent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; rv:11.0) like Gecko,gzip(gfe)', 'clientName': 'WEB', 'clientVersion': '2.20210827.01.00', 'osName': 'Windows', 'osVersion': '6.3', 'originalUrl': 'https://www.youtube.com/watch?v=2HyspUw5L0U', 'platform': 'DESKTOP', 'clientFormFactor': 'UNKNOWN_FORM_FACTOR', 'browserName': 'IE', 'browserVersion': '11.0'}, 'user': {'lockedSafetyMode': False}, 'request': {'useSsl': True}, 'clickTracking': {'clickTrackingParams': 'IhMIi/Kd9LHW8gIV4pDCCh3ePAoi'}}, 'continuation': 'Eg0SCzJIeXNwVXc1TDBVGAYyfhpLEhpVZ3dTUGxuUHB4WGJkbTM0VmdaNEFhQUJBZyICCAAqGFVDeVBNLVEtLXF6eWNVZEg2UU9OYTZ6dzILMkh5c3BVdzVMMFVAAUgKQi9jb21tZW50LXJlcGxpZXMtaXRlbS1VZ3dTUGxuUHB4WGJkbTM0VmdaNEFhQUJBZw%3D%3D'}
# {'댓글': 'Huh', '좋아요': '4'}
# {'댓글': "Because you're a girl, it's natural to like boy groups", '좋아요': '23'}
# {'댓글': 'who said that?', '좋아요': '10'}
# {'댓글': 'What boyband you mean compare to aespa? All boyband or you have one biased? Tell me ⚠️', '좋아요': '6'}
# {'댓글': "\xa0@Irene Irene\xa0 I mean they dance so bad, Taemin's shows amazing", '좋아요': '1'}
# {'댓글': 'U BLIND~', '좋아요': '3'}
# {'댓글': '\xa0@Kattyy707\xa0 beda lah cok koreo girl sama boy, cobak kau split bisa gak? dance dikit aja encok kau babi.', '좋아요': '0'}
# {'댓글': 'Bc they are boys', '좋아요': '0'}
# {'댓글': '\xa0@Nahid Ibrahimi\xa0 no, u r wrong coz this girls cant dance, children dance better🤣🤣🤣 Taemin dance godest', '좋아요': '1'}
# {'댓글': 'Cuz ur misogynistic', '좋아요': '1'}

# %%
# with open('8.29_aespa_youtube_comments.csv', "w") as file1:
#     writes = csv.writer(file1, delimiter=' ', quoting=csv.QUOTE_ALL)
#     for item in download_comments():
#         writes.writerow(item.values())


    # writes.writerows(download_comments())
