# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser
import pandas as pd
# https://yobro.tistory.com/190

# %%
key = 'AIzaSyDO7dPJcu4TqdRXu3kvz4KIZpGtVPxeYoo'
api_service = 'youtube'
api_ver = 'v3'
url_format = 'https://www.youtube.com/watch?v='

# %%
youtube = build(api_service, api_ver, developerKey=key)

# %%
search_response = youtube.search().list(
    # q = 유튜브 검색어
    q = 'aespa',
    order = 'relevance',
    part = 'snippet',
    maxResults = 10
).execute()

# %%
channel_id = search_response['items'][0]['id']['channelId']
channel_id
# Out:
# 'UC9GtSLeksfK4yuJ_g1lgQbg'

# %%
playlists = youtube.playlists().list(
    channelId = channel_id,
    part = 'snippet',
    maxResults = 20
).execute()
playlists
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': 'MWZodpyKj4OxyuGMmHFe99vPPdA',
#  'pageInfo': {'totalResults': 9, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': 'p9_OB618y8ItBrkpk8cWGm7UTlg',
#    'id': 'PLinm7-cvTdN78PPU4PaDFxT1isqKrBUE3',
#    'snippet': {'publishedAt': '2021-05-13T10:35:47Z',
#     'channelId': 'UC9GtSLeksfK4yuJ_g1lgQbg',
#     'title': 'Next Level',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4TWR90KJl84/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4TWR90KJl84/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4TWR90KJl84/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/4TWR90KJl84/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/4TWR90KJl84/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'aespa',
#     'localized': {'title': 'Next Level', 'description': ''}}},
#   {'kind': 'youtube#playlist',
#    'etag': 'KBLwvqfwXXw9KesRtdCVmu0dG3s',
#    'id': 'PLinm7-cvTdN7MPhZvPjddQVAyBR-vmJvc',
#    'snippet': {'publishedAt': '2021-03-05T10:09:03Z',
#     'channelId': 'UC9GtSLeksfK4yuJ_g1lgQbg',
#     'title': 'What’s in my bag with aespa👜',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xUEKF5FNmPQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xUEKF5FNmPQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xUEKF5FNmPQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/xUEKF5FNmPQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/xUEKF5FNmPQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'aespa',
#     'localized': {'title': 'What’s in my bag with aespa👜',
#      'description': ''}}},
#   {'kind': 'youtube#playlist',
#    'etag': 'GqH6_YsiCT0R_K2AfssuZhd17CA',
#    'id': 'PLinm7-cvTdN7d4HCUD4HDBkyqkJwMOz8s',
#    'snippet': {'publishedAt': '2021-02-24T11:06:54Z',
#     'channelId': 'UC9GtSLeksfK4yuJ_g1lgQbg',
#     'title': 'SYNK TIME with aespa',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5bi0H7VNqKE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5bi0H7VNqKE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5bi0H7VNqKE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/5bi0H7VNqKE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/5bi0H7VNqKE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'aespa',
#     'localized': {'title': 'SYNK TIME with aespa', 'description': ''}}},
#   {'kind': 'youtube#playlist',
#    'etag': 'ECOMVnajDktTjjyO4E-iEkl9c-M',
#    'id': 'PLinm7-cvTdN4gDNE7FKfqFFhwyOsijVZA',
#    'snippet': {'publishedAt': '2021-02-11T10:02:41Z',
#     'channelId': 'UC9GtSLeksfK4yuJ_g1lgQbg',
#     'title': '🧚🏻\u200d♀️뽀에버 요정단🧚🏻\u200d♀️ Forever Fairies',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uaGWqxIzW10/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uaGWqxIzW10/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uaGWqxIzW10/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/uaGWqxIzW10/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/uaGWqxIzW10/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'aespa',
#     'localized': {'title': '🧚🏻\u200d♀️뽀에버 요정단🧚🏻\u200d♀️ Forever Fairies',
#      'description': ''}}},
#   {'kind': 'youtube#playlist',
#    'etag': '1CYmmNfB-FdE58aJvdwE4KgyyYA',
#    'id': 'PLinm7-cvTdN5WJJWFnAN5vyiyylvPLeAp',
#    'snippet': {'publishedAt': '2021-02-01T06:42:17Z',
#     'channelId': 'UC9GtSLeksfK4yuJ_g1lgQbg',
#     'title': 'Forever',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wog1R1d4zls/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wog1R1d4zls/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wog1R1d4zls/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/wog1R1d4zls/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/wog1R1d4zls/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'aespa',
#     'localized': {'title': 'Forever', 'description': ''}}},
#   {'kind': 'youtube#playlist',
#    'etag': 'CTGCJH6HPiau55acu-1vRoqIvfk',
#    'id': 'PLinm7-cvTdN7r-Pu6gkJr8BOktousg3gE',
#    'snippet': {'publishedAt': '2020-12-23T10:01:11Z',
#     'channelId': 'UC9GtSLeksfK4yuJ_g1lgQbg',
#     'title': '🎄MerrY MerrY aespa🎄',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MxCE1sn2dLk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MxCE1sn2dLk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MxCE1sn2dLk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/MxCE1sn2dLk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/MxCE1sn2dLk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'aespa',
#     'localized': {'title': '🎄MerrY MerrY aespa🎄', 'description': ''}}},
#   {'kind': 'youtube#playlist',
#    'etag': 'a7E6O2tgEfJo-UXJYeIG_Mincjg',
#    'id': 'PLinm7-cvTdN6KSHDYZoGxHUkVhB60cdGn',
#    'snippet': {'publishedAt': '2020-12-05T10:10:38Z',
#     'channelId': 'UC9GtSLeksfK4yuJ_g1lgQbg',
#     'title': '✨MY time, aespa!✨',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/l70hgNTAPdo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/l70hgNTAPdo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/l70hgNTAPdo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/l70hgNTAPdo/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/l70hgNTAPdo/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'aespa',
#     'localized': {'title': '✨MY time, aespa!✨', 'description': ''}}},
#   {'kind': 'youtube#playlist',
#    'etag': 'nP80X2lUVJ8auMvwYormrfCob6Y',
#    'id': 'PLinm7-cvTdN7RqadpfNrncUGqkdyKNpn6',
#    'snippet': {'publishedAt': '2020-11-16T13:11:13Z',
#     'channelId': 'UC9GtSLeksfK4yuJ_g1lgQbg',
#     'title': 'Black Mamba',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZeerrnuLi5E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZeerrnuLi5E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZeerrnuLi5E/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/ZeerrnuLi5E/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/ZeerrnuLi5E/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'aespa',
#     'localized': {'title': 'Black Mamba', 'description': ''}}},
#   {'kind': 'youtube#playlist',
#    'etag': 'UTqid4jcpMBqbcszZUcRV9F_cr8',
#    'id': 'PLinm7-cvTdN6n9zc_0ggVNpWwiuKFGCVJ',
#    'snippet': {'publishedAt': '2020-10-25T15:55:02Z',
#     'channelId': 'UC9GtSLeksfK4yuJ_g1lgQbg',
#     'title': 'aespa PRESENTS',
#     'description': "Subscribe aespa on YouTube and don't miss aespa's new updates!",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vMeoR3og40s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vMeoR3og40s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vMeoR3og40s/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/vMeoR3og40s/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/vMeoR3og40s/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'aespa',
#     'localized': {'title': 'aespa PRESENTS',
#      'description': "Subscribe aespa on YouTube and don't miss aespa's new updates!"}}}]}

# %%
ids = []
titles = []
for i in playlists['items']:
    ids.append(i['id'])
    titles.append(i['snippet']['title'])

# %%
df = pd.DataFrame([ids,titles]).transpose()
df.columns = ['플레이리스트_ID','제목']
df
# Out:
#                             플레이리스트_ID                                 제목
# 0  PLinm7-cvTdN78PPU4PaDFxT1isqKrBUE3                         Next Level
# 1  PLinm7-cvTdN7MPhZvPjddQVAyBR-vmJvc       What’s in my bag with aespa👜
# 2  PLinm7-cvTdN7d4HCUD4HDBkyqkJwMOz8s               SYNK TIME with aespa
# 3  PLinm7-cvTdN4gDNE7FKfqFFhwyOsijVZA  🧚🏻‍♀️뽀에버 요정단🧚🏻‍♀️ Forever Fairies
# 4  PLinm7-cvTdN5WJJWFnAN5vyiyylvPLeAp                            Forever
# 5  PLinm7-cvTdN7r-Pu6gkJr8BOktousg3gE                🎄MerrY MerrY aespa🎄
# 6  PLinm7-cvTdN6KSHDYZoGxHUkVhB60cdGn                  ✨MY time, aespa!✨
# 7  PLinm7-cvTdN7RqadpfNrncUGqkdyKNpn6                        Black Mamba
# 8  PLinm7-cvTdN6n9zc_0ggVNpWwiuKFGCVJ                     aespa PRESENTS

# %%
playlist_videos = youtube.playlistItems().list(
    playlistId = df['플레이리스트_ID'][0],
    part = 'snippet'
    , maxResults=50
)
list_response = playlist_videos.execute()
# print(list_response)

video_names =[]
video_ids=[]
date=[]
url=[]

for v in list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])
    url.append(url_format+v['snippet']['resourceId']['videoId'])

table = pd.DataFrame([date,video_names,video_ids,url]).transpose()
table.columns = ['날짜','영상제목','ID','url']
table
# Out:
#                       날짜                                               영상제목  \
# 0   2021-05-17T09:01:28Z                          aespa 에스파 'Next Level' MV
# 1   2021-06-25T14:01:21Z  [K-Choreo 8K] 에스파 직캠 'Next Level' (aespa Chore...
# 2   2021-06-19T09:01:02Z  aespa 에스파 'Next Level' aespa Company ver. Danc...
# 3   2021-06-18T09:02:23Z           에스파 지켜!ㅣaespa 에스파 'Next Level' 음악방송 비하인드
# 4   2021-06-14T09:01:55Z  aespa 에스파 'ep1. Black Mamba' - SM Culture Univ...
# 5   2021-06-11T09:49:41Z        aespa 에스파 'Next Level' MV Behind The Scenes
# 6   2021-06-09T09:40:20Z    aespa 에스파 'Next Level' Jacket Behind The Scenes
# 7   2021-06-04T09:03:29Z  이번 의상은 City 느낌~🌇✨ | aespa 에스파 'Next Level' The...
# 8   2021-06-02T09:00:55Z  That’s my nævis It’s my nævis  | Choreography ...
# 9   2021-06-19T08:54:42Z  (ENG sub) [쇼! 음악중심] 에스파 - 넥스트 레벨 (aespa - Next...
# 10  2021-06-01T15:58:31Z  (Full Focused) aespa(에스파) 'Next Level' 4K | BE...
# 11  2021-06-19T08:54:52Z  [BE ORIGINAL] aespa(에스파) 'Next Level' (Behind)...
# 12  2021-05-27T09:00:44Z    aespa 에스파 'Next Level' The Performance Stage #3
# 13  2021-05-25T09:01:08Z    aespa 에스파 'Next Level' The Performance Stage #2
# 14  2021-05-20T09:00:48Z    aespa 에스파 'Next Level' The Performance Stage #1
# 9   gHxIOjZrrwA  https://www.youtube.com/watch?v=gHxIOjZrrwA
# 10  Yw_I29NKvbI  https://www.youtube.com/watch?v=Yw_I29NKvbI
# 11  AHrUrrPTmQk  https://www.youtube.com/watch?v=AHrUrrPTmQk
# 12  82CnK4M2sxo  https://www.youtube.com/watch?v=82CnK4M2sxo
# 13  hehFXvnWyKo  https://www.youtube.com/watch?v=hehFXvnWyKo
# 14  z58k37I4Crs  https://www.youtube.com/watch?v=z58k37I4Crs
# 15  4bus7zF6K-Y  https://www.youtube.com/watch?v=4bus7zF6K-Y
# 16  8b9WiId0gMw  https://www.youtube.com/watch?v=8b9WiId0gMw
# 17  2NR4BgNfiVY  https://www.youtube.com/watch?v=2NR4BgNfiVY
# 18  DJKrpeQootU  https://www.youtube.com/watch?v=DJKrpeQootU
# 19  VZVSy8H-uzY  https://www.youtube.com/watch?v=VZVSy8H-uzY
# 20  9xBSLI7EsTg  https://www.youtube.com/watch?v=9xBSLI7EsTg
# 21  B9Is5RIpeuI  https://www.youtube.com/watch?v=B9Is5RIpeuI
# 22  8rNmPbOTAis  https://www.youtube.com/watch?v=8rNmPbOTAis
# 23  boxEVuTRFP8  https://www.youtube.com/watch?v=boxEVuTRFP8
# 24  nmgcgXPkX7E  https://www.youtube.com/watch?v=nmgcgXPkX7E
# 25  bQduRf0aQp0  https://www.youtube.com/watch?v=bQduRf0aQp0
# 26  PFEhy5rBUC0  https://www.youtube.com/watch?v=PFEhy5rBUC0
# 27  9y9RxcTzsC0  https://www.youtube.com/watch?v=9y9RxcTzsC0
# 28  hVBSsQPj9Mw  https://www.youtube.com/watch?v=hVBSsQPj9Mw
# 29  OU94ZF2Iqwk  https://www.youtube.com/watch?v=OU94ZF2Iqwk
# 30  KAE_FYqra4c  https://www.youtube.com/watch?v=KAE_FYqra4c
# 31  5tPmx9vnI9w  https://www.youtube.com/watch?v=5tPmx9vnI9w
# 32  kxnkvTSJJhA  https://www.youtube.com/watch?v=kxnkvTSJJhA
# 33  UGrpwyQH8UI  https://www.youtube.com/watch?v=UGrpwyQH8UI
# 34  YBAhQBJksMw  https://www.youtube.com/watch?v=YBAhQBJksMw
# 35  tkzYyEp4zB4  https://www.youtube.com/watch?v=tkzYyEp4zB4
# 36  3HAZ07Jaoq4  https://www.youtube.com/watch?v=3HAZ07Jaoq4
# 37  vbH4Lk5wYWg  https://www.youtube.com/watch?v=vbH4Lk5wYWg

# %%
import re

category_id = []
views = []
likes = []
dislikes = []
comments = []
mins = []
seconds = []
title = []

for u in range(len(table)):
    request = youtube.videos().list(
        part='snippet,contentDetails,statistics'
        ,id=table['ID'][u]
    )

    response = request.execute()

    if response['items'] == []:
        ids.append('-')
        category_id.append('-')
        views.append('-')
        likes.append('-')
        dislikes.append('-')
        comments.append('-')
    else:
        title.append(response['items'][0]['snippet']['title'])
        category_id.append(response['items'][0]['snippet']['categoryId'])
        views.append(response['items'][0]['statistics']['viewCount'])
        likes.append(response['items'][0]['statistics']['likeCount'])
        dislikes.append(response['items'][0]['statistics']['dislikeCount'])
        comments.append(response['items'][0]['statistics']['commentCount'])

table_2 = pd.DataFrame([title,views,likes,dislikes,comments,url]).T
table_2.columns = ['제목','조회수','좋아요','싫어요','댓글수','url']
table_2
# Out:
#                                                    제목        조회수      좋아요  \
# 0                           aespa 에스파 'Next Level' MV  143757988  2642922
# 1   [K-Choreo 8K] 에스파 직캠 'Next Level' (aespa Chore...    2524191    76990
# 2   aespa 에스파 'Next Level' aespa Company ver. Danc...   10380255   452240
# 3            에스파 지켜!ㅣaespa 에스파 'Next Level' 음악방송 비하인드     691685    52347
# 4   aespa 에스파 'ep1. Black Mamba' - SM Culture Univ...    1596356   120636
# 5         aespa 에스파 'Next Level' MV Behind The Scenes    1137932    87872
# 6     aespa 에스파 'Next Level' Jacket Behind The Scenes    1301305    79472
# 7   이번 의상은 City 느낌~🌇✨ | aespa 에스파 'Next Level' The...     921000    62007
# 8   That’s my nævis It’s my nævis  | Choreography ...    1431331    97898
# 9   (ENG sub) [쇼! 음악중심] 에스파 - 넥스트 레벨 (aespa - Next...    1540063    26573
# 10  (Full Focused) aespa(에스파) 'Next Level' 4K | BE...    5817569   178338
# 11  [BE ORIGINAL] aespa(에스파) 'Next Level' (Behind)...     391699    30628
# 12    aespa 에스파 'Next Level' The Performance Stage #3    7392133   351298
# 13    aespa 에스파 'Next Level' The Performance Stage #2    8041391   348455
# 14    aespa 에스파 'Next Level' The Performance Stage #1   10703448   532329
# 15               [릴레이댄스] aespa(에스파) - Next Level (4K)   13398805   429926
# 16  [안방1열 직캠4K] 에스파 'Next Level' 풀캠 (aespa Full Ca...    2023662    57369
# 17  [K-Choreo 8K HDR] 에스파 직캠 'Next Level' (aespa C...    2201175    66221
# 18  aespa - Next Level (Music Bank) | KBS WORLD TV...    1917484   140018
# 19         [공유] aespa - Next Level 선생님 안무 컨펌 영상 공유의 건   20587024   679873
# 20         [BE ORIGINAL] aespa(에스파) 'Next Level' (4K)   18623326   596814
# 21           다 잘할 준비됐죠?😉 | aespa 에스파 ‘Next Level’ 응원법     692427    62049
# 22  에스파 세계관 흑막은 누구? 원더케이는 윈터 흑막설에 치킨 걸었음 | 에스파(aes...    2686031    70409
# 23  [페이스캠4K] 에스파 윈터 'Next Level' (aespa WINTER Fac...          -        -
# 24  [페이스캠4K] 에스파 지젤 'Next Level' (aespa GISELLE Fa...    2177795    48182
# 25  [페이스캠4K] 에스파 닝닝 'Next Level' (aespa NINGNING F...     278996    11969
# 26  [페이스캠4K] 에스파 카리나 'Next Level' (aespa KARINA Fa...     787443    27727
# 27  [UNFILTERED CAM] aespa KARINA(카리나) 'Next Level...    1229064    33156
# 28  [UNFILTERED CAM] aespa NINGNING(닝닝) 'Next Leve...    1293641    56697
# 29  [UNFILTERED CAM] aespa GISELLE(지젤) 'Next Level...     269865    22980
# 30  [UNFILTERED CAM] aespa WINTER(윈터) 'Next Level'...     356432    28011
# 31     SHINee TAEMIN Reaction | aespa 'Next Level' MV     958832    41319
# 32  SUPER JUNIOR LEETEUK Reaction | aespa ‘Next Le...    1410817   126871
