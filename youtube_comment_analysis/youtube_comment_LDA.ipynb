# %%
# -*- coding: utf-8 -*-
"""유튜브_댓글_분석_안성근.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1DhPGwp5xjkm3_QaQfZW_o1irN8XaSdbZ

# 텍스트 분석 라이브러리 초기화
"""
# Commented out IPython magic to ensure Python compatibility.
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# %matplotlib inline
# 시각화 결과가 선명하게 표시
# %config InlineBackend.figure_fromat = 'retina'
# range 대신 처리 시간을 알려주는 라이브러리
from tqdm import trange

# %%
"""# 시각화를 위한 한글폰트 설정"""

# 윈도우 한글폰트 설정
plt.rc("font", family='Malgun Gothic')

# %%
artist_name=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/[공유] Mulcam_Army 공유폴더!/아티스트이름 - Sheet1.csv')
name=artist_name['engName']
name.dropna(inplace=True)
name=name.reset_index()
name.drop(['index'],axis=1, inplace=True)
name
# Out:
#               engName
# 0                GOT7
# 1        GOLDEN CHILD
# 2        KIM SE JEONG
# 3         KIM JAEHWAN
# 4              NU_EST
# 5            THE BOYZ
# 6                DAY6
# 7          RED VELVET
# 8             MAMAMOO
# 9            MONSTA X
# 10        PARK JIHOON
# 11        Brave Girls
# 12            BLOCK B
# 13          BLACKPINK
# 14               BTOB
# 15             VICTON
# 16             SHINee
# 17          SEVENTEEN
# 18  GIRLS_ GENERATION
# 19              STAYC
# 20       SUPER JUNIOR
# 21         Stray Kids
# 22           (G)I-DLE
# 23              ASTRO
# 24                 IU
# 25             IZ_ONE
# 26               AKMU
# 27                SF9
# 28              aespa
# 29              AB6IX
# 30              ATEEZ
# 31              APINK
# 32                EXO
# 33                NCT
# 34           N.Flying
# 35            ENHYPEN
# 36            GFRIEND
# 37         OH MY GIRL
# 38                ONF
# 39              ONEUS
# 40              WONHO
# 41             WINNER
# 42                WEi
# 43            WEEEKLY
# 44              LOONA
# 45               ITZY
# 46       JEONG SEWOON
# 47            CRAVITY
# 48                TXT
# 49                2PM
# 50           TREASURE
# 51              TWICE
# 52           PENTAGON
# 53        PURPLE KISS
# 54           fromis_9
# 55       HA SUNG WOON
# 56          HIGHLIGHT

# %%
name.drop([3,5,24,29,37,38,48],axis=0, inplace=True)
name=name.reset_index()
name.drop(['index'],axis=1, inplace=True)
name
# Out:
#               engName
# 0                GOT7
# 1        GOLDEN CHILD
# 2        KIM SE JEONG
# 3              NU_EST
# 4                DAY6
# 5          RED VELVET
# 6             MAMAMOO
# 7            MONSTA X
# 8         PARK JIHOON
# 9         Brave Girls
# 10            BLOCK B
# 11          BLACKPINK
# 12               BTOB
# 13             VICTON
# 14             SHINee
# 15          SEVENTEEN
# 16  GIRLS_ GENERATION
# 17              STAYC
# 18       SUPER JUNIOR
# 19         Stray Kids
# 20           (G)I-DLE
# 21              ASTRO
# 22             IZ_ONE
# 23               AKMU
# 24                SF9
# 25              aespa
# 26              ATEEZ
# 27              APINK
# 28                EXO
# 29                NCT
# 30           N.Flying
# 31            ENHYPEN
# 32            GFRIEND
# 33              ONEUS
# 34              WONHO
# 35             WINNER
# 36                WEi
# 37            WEEEKLY
# 38              LOONA
# 39               ITZY
# 40       JEONG SEWOON
# 41            CRAVITY
# 42                2PM
# 43           TREASURE
# 44              TWICE
# 45           PENTAGON
# 46        PURPLE KISS
# 47           fromis_9
# 48       HA SUNG WOON
# 49          HIGHLIGHT

# %%
# 유튜브 크롤링 파일 로드
path = '/content/drive/MyDrive/Colab Notebooks/[공유] Mulcam_Army 공유폴더!/크롤링 한 자료/youtube/영상별 댓글/'

frames=[]
keys = []
for i in range(len(name['engName'])):
    temp=name['engName'][i]
    comment_file = f'comments_youtube_{temp}.csv'     #GOT7
    df = pd.read_csv(path+comment_file, encoding='utf-8', header=None)
    # print(df)
    # print('\n')
    frames.append(df)
    keys.append(temp)

df = pd.concat(frames, ignore_index=True)
df.columns=['comment','like']

# %%
df
# Out:
#                                                   comment like
# 0       wish all the best for this boy, he deserves mo...  255
# 1       can’t believe how underrated it is and how muc...   27
# 2       이 곡을 왜 타이틀로 뽑았는지 알겠다.. 귀에 박히는 멜로디와 하성운만의 특색있는 ...   20
# 3       I seriously love his music, it is so diverse a...   88
# 4       It's so sad to know that his group is being de...  198
# ...                                                   ...  ...
# 388750  엥 ?! 일주일 중 가장 지치는 수요일 날에 이런 걸 올려주시다니 그저 감사를......    1
# 388751  하이라이트의 메인댄서이자 춤신춤왕 이기광의 안무연습을 이렇게 많이 보다니ㅠㅠㅠㅠ 너...   11
# 388752  전지적 라이트 입장 : 댄서와 안무가가 느므 화려해서 우리 아티스트랑 구분이 안감 ...    0
# 388753  yeeeeeessssss eng subs are here\r\ny\r\ne\r\ne...    0
# 388754  They did nowadays but it takes some time. Mayb...    1
#
# [388755 rows x 2 columns]

# %%
# temp=name['engName'][0]
# temp1=name['engName'][1]


# comment_file0 = f'comments_youtube_{temp}.csv'     #GOT7
# df0 = pd.read_csv(path+comment_file0, encoding='utf-8', header=None)
# df0
# comment_file1 = f'comments_youtube_{temp1}.csv'     #GOT7
# df1 = pd.read_csv(path+comment_file1, encoding='utf-8', header=None)
# df1
# frames=[df0,df1]
# keys = [temp,temp1]
# df = pd.concat(frames, ignore_index=True)
# df.columns=['comment','like']
# df

# frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]
# keys = ['shinee','sf9','seventeen','red_velvet','purple_kiss','pentagon','park_jihoon','oneus','nuest','nct']

# # df.loc['key_name']으로 데이터 프레임만 따로 뽑아낼 수 있다.
# # df = pd.concat(frames,keys=keys,ignore_index=True)
# df = pd.concat(frames, ignore_index=True)
# df.columns=['comment','like']
# df

# """# 유튜브 크롤링 파일 로드"""

# path = '/content/drive/MyDrive/Colab Notebooks/[공유] Mulcam_Army 공유폴더!/크롤링 한 자료/youtube/영상별 댓글/'

# shinee = 'comments_youtube_SHINee.csv'
# sf9 = 'comments_youtube_SF9.csv'
# seventeen = 'comments_youtube_SEVENTEEN.csv'
# red_velvet = 'comments_youtube_RED VELVET.csv'
# purple_kiss = 'comments_youtube_PURPLE KISS.csv'
# pentagon = 'comments_youtube_PENTAGON.csv'
# park_jihoon = 'comments_youtube_PARK JIHOON.csv'
# oneus = 'comments_youtube_ONEUS.csv'
# nuest = "comments_youtube_NU'EST.csv"
# nct = "comments_youtube_NCT.csv"

# df1 = pd.read_csv(path+shinee, encoding='utf-8', header=None)
# df2 = pd.read_csv(path+sf9, encoding='utf-8', header=None)
# df3 = pd.read_csv(path+seventeen, encoding='utf-8', header=None)
# df4 = pd.read_csv(path+red_velvet, encoding='utf-8', header=None)
# df5 = pd.read_csv(path+purple_kiss, encoding='utf-8', header=None)
# df6 = pd.read_csv(path+pentagon, encoding='utf-8', header=None)
# df7 = pd.read_csv(path+park_jihoon, encoding='utf-8', header=None)
# df8 = pd.read_csv(path+oneus, encoding='utf-8', header=None)
# df9 = pd.read_csv(path+nuest, encoding='utf-8', header=None)
# df10 = pd.read_csv(path+nct, encoding='utf-8', header=None)

# frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]
# keys = ['shinee','sf9','seventeen','red_velvet','purple_kiss','pentagon','park_jihoon','oneus','nuest','nct']

# # df.loc['key_name']으로 데이터 프레임만 따로 뽑아낼 수 있다.
# # df = pd.concat(frames,keys=keys,ignore_index=True)
# df = pd.concat(frames, ignore_index=True)
# df.columns=['comment','like']
# df

# %%
"""# 네트워크 오류 등으로 발생한 중복 입력 값 제거
- 빈도 수 중복 방지
- 대문자 소문자로 바꾸기
"""

# 중복 값 제거
print('중복 제거 전 :',df.shape)
df = df.drop_duplicates(['comment'],keep='last',ignore_index=True)
print('중복 제거 후 :',df.shape)

# 소문자로 바꾸기
df['comment'] = df['comment'].str.lower()
# copy_data.to_csv('concat_txt.csv',encoding='utf-8-sig')
df
# Out:
# 중복 제거 전 : (388755, 2)
# 중복 제거 후 : (211030, 2)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#                                                   comment like
# 0                                       wow nice songggg!    2
# 1                                            rumo a 1b!!!    1
# 2       jisoo xinh xuất sắt, đẹp quá mấy chị iu ơi. ch...  263
# 3       this is wow!!! music structure, dance, fashion...    2
# 4       this song is really so good! ktl had to grow o...    2
# ...                                                   ...  ...
# 211025  엥 ?! 일주일 중 가장 지치는 수요일 날에 이런 걸 올려주시다니 그저 감사를......    1
# 211026  하이라이트의 메인댄서이자 춤신춤왕 이기광의 안무연습을 이렇게 많이 보다니ㅠㅠㅠㅠ 너...   11
# 211027  전지적 라이트 입장 : 댄서와 안무가가 느므 화려해서 우리 아티스트랑 구분이 안감 ...    0
# 211028  yeeeeeessssss eng subs are here\r\ny\r\ne\r\ne...    0
# 211029  they did nowadays but it takes some time. mayb...    1
#
# [211030 rows x 2 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/[공유] Mulcam_Army 공유폴더!/comment_all.csv')

# %%
"""# 텍스트 전처리 1차 작업"""

# 전처리 전 원본 보존
import copy
copy_data = copy.deepcopy(df)
copy_data.info()

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

#분석에 어긋나는 불용어구 제외 (특수문자, 의성어)
han = re.compile(r'[ㄱ-ㅎㅏ-ㅣ!?~,".\n\r#\ufeff\u200d]')

comment_result = []

for i in copy_data['comment'].values:
    tokens = re.sub(emoji_pattern,"",i)
    tokens = re.sub(han,"",tokens)
    comment_result.append(tokens)

# 이모티콘 의성어 제대로 안 없어 졌다.
# comment_result
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211030 entries, 0 to 211029
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   comment  211030 non-null  object
#  1   like     211030 non-null  object
# dtypes: object(2)
# memory usage: 3.2+ MB

# %%
punct = "/-'?!.,#$%\'()*+-/:;<=>@[\\]^_`{|}~" + '""“”’' + '∞θ÷α•à−β∅³π‘₹´°£€\×™√²—–&'

punct_mapping = {"‘": "'", "₹": "e", "´": "'", "°": "", "€": "e", "™": "tm", "√": " sqrt ", "×": "x", "²": "2", "—": "-", "–": "-", "’": "'", "_": "-", "`": "'", '“': '"', '”': '"', '“': '"', "£": "e", '∞': 'infinity', 'θ': 'theta', '÷': '/', 'α': 'alpha', '•': '.', 'à': 'a', '−': '-', 'β': 'beta', '∅': '', '³': '3', 'π': 'pi', }

def clean_punc(text, punct, mapping):
    for p in mapping:
        text = text.replace(p, mapping[p])
    
    for p in punct:
        text = text.replace(p, f' {p} ')
    
    specials = {'\u200b': ' ', '…': ' ... ', '\ufeff': '', 'करना': '', 'है': ''}
    for s in specials:
        text = text.replace(s, specials[s])
    
    return text.strip()

cleaned_corpus = []
for sent in comment_result:
    cleaned_corpus.append(clean_punc(sent, punct, punct_mapping))

cleaned_corpus[:10]
# Out:
# ['wow nice songggg',
#  'rumo a 1b',
#  'jisoo xinh xuất sắt đẹp quá mấy chị iu ơi chúc mừng mấy chị',
#  'this is wow music structure dance fashion color stunning revolutionary pop',
#  'this song is really so good ktl had to grow on me but when i listened to this the first time  i immediately loved it the chorus and everything was so catchy',
#  'lam on dung post emoji',
#  '@ phuong  -   xox',
#  '@ khang nguyễn\xa0 họ đóng băng các lượt xem  ( xin lỗi nếu bạn không hiểu tôi đã gỡ bỏ google dịch nay )',
#  "jennytthao emoji does not freeze views youtube can check if those view are real if not they  '  ll freeze it",
#  'jennytthao unless your comment only have emojis']

# %%
def clean_text(texts):
    corpus = []
    for i in range(0, len(texts)):
        review = re.sub(r'[@%\\*=()/~#&\+á?\xc3\xa1\-\|\.\:\;\!\-\,\_\~\$\'\"]', '',str(texts[i])) #remove punctuation
        review = re.sub(r'\d+','', str(texts[i]))# remove number
        review = review.lower() #lower case
        review = re.sub(r'\s+', ' ', review) #remove extra space
        review = re.sub(r'<[^>]+>','',review) #remove Html tags
        review = re.sub(r'\s+', ' ', review) #remove spaces
        review = re.sub(r"^\s+", '', review) #remove space from start
        review = re.sub(r'\s+$', '', review) #remove space from the end
        corpus.append(review)
    return corpus

basic_preprocessed_corpus = clean_text(cleaned_corpus)
comment_result = pd.DataFrame(basic_preprocessed_corpus, columns=["comment"])
comment_result
# Out:
#                                                   comment
# 0                                        wow nice songggg
# 1                                                rumo a b
# 2       jisoo xinh xuất sắt đẹp quá mấy chị iu ơi chúc...
# 3       this is wow music structure dance fashion colo...
# 4       this song is really so good ktl had to grow on...
# ...                                                   ...
# 211025  엥 일주일 중 가장 지치는 수요일 날에 이런 걸 올려주시다니 그저 감사를 어빠들 춤...
# 211026  하이라이트의 메인댄서이자 춤신춤왕 이기광의 안무연습을 이렇게 많이 보다니 너무좋다 ...
# 211027  전지적 라이트 입장 : 댄서와 안무가가 느므 화려해서 우리 아티스트랑 구분이 안감 ...
# 211028  yeeeeeessssss eng subs are hereyeeeeeeeeeeeest...
# 211029  they did nowadays but it takes some time maybe...
#
# [211030 rows x 1 columns]

# %%
"""# 언어별 분류 작업
- 정확도가 높은 fasttext 모듈로 분류
"""

# !pip install fasttext
# Out:
# Requirement already satisfied: fasttext in /usr/local/lib/python3.7/dist-packages (0.9.2)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext) (57.4.0)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext) (2.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fasttext) (1.19.5)

# %%
import fasttext
model = fasttext.load_model('/content/drive/MyDrive/Colab Notebooks/[공유] Mulcam_Army 공유폴더!/lid.176.ftz')

predict = []
for t in comment_result.comment.values:
  predict.append(model.predict(t,k=1))

ty = pd.DataFrame(predict)

comment = []
for num, txt in enumerate(ty[0]):
  #print(txt)
  #if num == 30:
   # break
  
  txt = str(txt)

  if txt == "('__label__ko',)":
    b = re.sub(txt,"ko",txt)
    comment.append(b)
  elif txt == "('__label__en',)":
    b = re.sub(txt,"en",txt)
    comment.append(b)
  elif txt == "('__label__id',)":
    b = re.sub(txt,"id",txt)
    comment.append(b)
  else:
    b = re.sub(txt,"etc",txt)
    comment.append(b)


comment[:10]
comment = pd.DataFrame(comment)
comment
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
#             0
# 0        (en)
# 1       (etc)
# 2       (etc)
# 3        (en)
# 4        (en)
# ...       ...
# 211025   (ko)
# 211026   (ko)
# 211027   (ko)
# 211028   (en)
# 211029   (en)
#
# [211030 rows x 1 columns]

# %%
pd.set_option('max_columns',50)
pd.set_option('max_rows',100)
# ty[0].value_counts()
# ty_sum.to_csv('ty_sum.csv', encoding='cp949')

like = pd.DataFrame(copy_data['like'])
data = pd.concat([comment_result,like, comment],axis=1)

data.columns = ['comment','like','lang']
data
# Out:
#                                                   comment like   lang
# 0                                        wow nice songggg    2   (en)
# 1                                                rumo a b    1  (etc)
# 2       jisoo xinh xuất sắt đẹp quá mấy chị iu ơi chúc...  263  (etc)
# 3       this is wow music structure dance fashion colo...    2   (en)
# 4       this song is really so good ktl had to grow on...    2   (en)
# ...                                                   ...  ...    ...
# 211025  엥 일주일 중 가장 지치는 수요일 날에 이런 걸 올려주시다니 그저 감사를 어빠들 춤...    1   (ko)
# 211026  하이라이트의 메인댄서이자 춤신춤왕 이기광의 안무연습을 이렇게 많이 보다니 너무좋다 ...   11   (ko)
# 211027  전지적 라이트 입장 : 댄서와 안무가가 느므 화려해서 우리 아티스트랑 구분이 안감 ...    0   (ko)
# 211028  yeeeeeessssss eng subs are hereyeeeeeeeeeeeest...    0   (en)
# 211029  they did nowadays but it takes some time maybe...    1   (en)
#
# [211030 rows x 3 columns]

# %%
data_ko = pd.DataFrame([kor[:1] for kor in data.values if kor[2] == '(ko)'], columns=['comment'])
data_en = pd.DataFrame([en[:1] for en in data.values if en[2] == '(en)'], columns=['comment'])

data_ko.comment.values
# Out:
# array(['와 진짜 목소리 대박인데근데 양손은 서로 가위바위보하는 건가요',
#        '정말 많이 들었구나아이유 노래는 디테일들이 엄청많고 정교해서커버곡내도 느낌을 내는게 어려운데정말 많이 노력하신게 느껴지네요 최고다 김세정',
#        '아이유 외의 가수가 이렇게 완벽하게 부를 줄 몰랐다', ...,
#        '엥 일주일 중 가장 지치는 수요일 날에 이런 걸 올려주시다니 그저 감사를 어빠들 춤선 다들 너무 예쁘구여 너무 좋구요 사랑하구요 아아악 너무 좋으면 어떻게 말을 해야할지 갈피를 잃어버리요 그저 사랑한다는 말만 . . . 하이라이트 짱이',
#        '하이라이트의 메인댄서이자 춤신춤왕 이기광의 안무연습을 이렇게 많이 보다니 너무좋다 역쉬 댄스왕답다 이기광 프로답게 디테일 하나하나 세심하게 더 멋있어 보이는 동작으로 계속 수정해 나가는 모습 진짜 섹시하고 개멋있다❤ 눈감고 집중하며 연습하는거는 진짜 너무너무너무다 미쳤다 진짜강약조절 춤선 너무 완벽하고 깔끔하고 예뻐턴도는거 정말 잘해춤추고 노래하는 내가수 이기광 정말 최고야 기광몰이당하는 순둥이 기광이 정말 사랑스러워서 어쩌냐 이뻐죽게쒀 쁘이하며 안녕하는 잔망스러운 기광이 진짜 미치게 귀엽구 눈이부시게 잘생겼어 이러다가 노래하고 춤출때 뽝눈빛 변하는거 미쳤다구끊임없이 노력하고 연습하는 나의자랑이자 귀여운 춤짱 음색킹 이기광 사랑해',
#        '전지적 라이트 입장 : 댄서와 안무가가 느므 화려해서 우리 아티스트랑 구분이 안감 문신 귀걸이팔찌모자염색 까지 더 아이돌같이 하고 있음 할랕이 워낙에 뽐안내고 수수하게 입지만서도'],
#       dtype=object)

# %% [markdown]
# ## 한글 만

# %%
"""# 텍스트 전처리 2차 작업"""



# !proper installation of python3
# !proper installation of pip

# !pip install tensorflow
# !pip install keras
# !pip install git+https://github.com/ssut/py-hanspell.git
# Out:
# Collecting git+https://github.com/ssut/py-hanspell.git
#   Cloning https://github.com/ssut/py-hanspell.git to /tmp/pip-req-build-qxeojitq
#   Running command git clone -q https://github.com/ssut/py-hanspell.git /tmp/pip-req-build-qxeojitq
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from py-hanspell==1.1) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->py-hanspell==1.1) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->py-hanspell==1.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->py-hanspell==1.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->py-hanspell==1.1) (3.0.4)

# %%
'''!curl -c ./cookie -s -L "https://drive.google.com/uc?export=download&id=1RNYpLE-xbMCGtiEHIoNsCmfcyJP3kLYn" > /dev/null
# !curl -Lb ./cookie "https://drive.google.com/uc?export=download&confirm=`awk '/download/ {print $NF}' ./cookie`&id=1RNYpLE-xbMCGtiEHIoNsCmfcyJP3kLYn" -o confused_loanwords.txt
'''

'''lownword_map = {}
lownword_data = open('/content/confused_loanwords.txt', 'r', encoding='utf-8')

lines = lownword_data.readlines()

for line in lines:
    line = line.strip()
    miss_spell = line.split('\t')[0]
    ori_word = line.split('\t')[1]
    lownword_map[miss_spell] = ori_word'''

'''# 스펠링 및 띄어쓰기 검사
from hanspell import spell_checker
from soynlp.normalizer import *

# 테스트
sent = "대체 왜 않돼는지 설명을 해바"
spelled_sent = spell_checker.check(sent)
checked_sent = spelled_sent.checked
 
print(checked_sent)

print(repeat_normalize('와하하하하하하하하하핫', num_repeats=2))'''

'''def spell_check_text(texts):
    
  corpus = []
  for sent in texts:

    sent = str(sent)
    spelled_sent = spell_checker.check(sent)
    checked_sent = spelled_sent.checked
    normalized_sent = repeat_normalize(checked_sent)

#    for lownword in lownword_map:
#      normalized_sent = normalized_sent.replace(lownword, lownword_map[lownword])
    corpus.append(normalized_sent)
  return corpus

'''

# 에러 이유를 모르겠다
''' spell_preprocessed_corpus = spell_check_text(a)

 File "<string>", line unknown
ParseError: not well-formed (invalid token): line 1, column 192 '''
# Out:
# ' spell_preprocessed_corpus = spell_check_text(a)\n\n File "<string>", line unknown\nParseError: not well-formed (invalid token): line 1, column 192 '

# %%
# 숫자제거 / 밑줄 제외한 특수문자 제거
p = re.compile("[0-9]+")
q = re.compile("\W+")
r = re.compile('[^ ㄱ-ㅣ가-힣]+')

kr = []

for i in data_ko.comment.values:
  tokens = re.sub(p," ",i)
  tokens = re.sub(q," ",tokens)
  tokens = re.sub(r," ", tokens)
  kr.append(tokens)

# %%
kr
# Out:
# ['와 진짜 목소리 대박인데근데 양손은 서로 가위바위보하는 건가요',
#  '정말 많이 들었구나아이유 노래는 디테일들이 엄청많고 정교해서커버곡내도 느낌을 내는게 어려운데정말 많이 노력하신게 느껴지네요 최고다 김세정',
#  '아이유 외의 가수가 이렇게 완벽하게 부를 줄 몰랐다',
#  '아나바다 이 어려운 노래를 원곡 느낌 파괴하지 않고 세정님 스타일로 부른거 너무 멋있어요 개인적으로 아나바다 커버곡 중 최고예요',
#  '세정님 최근에 뮤지컬 하시면서 실력도 그렇고 감정 표현도 너무 늘었어요 목소리만으로도 마음이 울리네요 분명 별생각 없이 본 영상인 것 같은데 영상이 끝나고 나니까 눈물이 맺혀있는 고음 부분 올라가는 것도 더 탄탄해지고 안정적인 것 같아서 쫙 뻗을 때 깜짝 놀랐어요 항상 조용히 뒤에서 응원합니다 세정님 ',
#  '한음 한음 한소절 한소절 온마음을 다 하고있다는게 느껴진 순간이었던것 같습니다 진심을 다한 노래 목소리 감사합니다 큰 위로가 되었습니다',
#  '여러분이 찾던 그 파트 세정님 뮤지컬 하시더니 감정선이 미쳤네요',
#  '진지하게 댓글 읽다가 빵터졌다',
#  '감동파굌',
#  '이 댓글 보고나니깐 손밖에 안보여 ',
#  '아씨방심하다 터졌네',
#  '찌는 안내심',
#  '아쒸 내감동 내놔',
#  '아 영상 보기전에 이 댓글 봐서 눈이 계속 손으로 가잖아 ',
#  '젠장영상 다 보기도 전에 이글을 읽어버렸어 집중하긴 글렀네 푸풉',
#  ' 묵을 이긴 빠긴 싸움의 끝',
#  '안녕하세요 혼자 가위바위보 장인입니다 생각보다 재밌으니 친구들 앞에서 해보세요',
#  '듣고 또 듣고 부르고 또 연습해서 발성과 감정 까지 담아낼수 있게됐네요 생각 보다 노래에 엄청 시간을 투자해서 연습하나봐요 날이갈 수록 노래 실력이 일취월장하네요',
#  '댓글보니까 아이유가 뮤지컬하는걸 도 보고싶네요',
#  '최근 뮤지컬도 하고 다양한 경험을 하다 보니 노래에 담긴 서사를 듣는 이가 느끼도록 표현하는 능력이 훨씬 뛰어나지신 것 같아요 세정 씨 온 세상이 언제나 응원합니다',
#  '노래 한소절 한소절에 진심을 눌러담아 부른 게 느껴져서 숨 죽이고 가만히 듣다가 울컥하네요 마지막쯤에 나오는 글도 좋았어요 노래해줘서 고마워요',
#  '지금 이 스타일 완전히 언니 것이 된거같아여 노래 한 소절 한 소절 아끼면서 부르는게 느껴져요 듣기 좋은 커버 감사합니다',
#  '이분은 노래도 음청잘하고 연기도잘하는 뮤지컬배우이자 가수이자 연기자인 다재다능한 연예인임 그리고 이쁨',
#  '감정선 최고다 그대로 감정들이 전달이되네요 아나바다 정말 나왔을때부터 많이 좋아했던 노래라 레슨곡으로 불렀었는데 이렇게 언니버젼으로 들을 수 있어 감사해요 ',
#  '지금까지 그냥 노래만 듣던 사람인데 이 영상으로 팬이 됐습니다 돌이켜보니 당신의 노래로 참 많은 위로를 받은 것 같아요 터널도 그렇고 오늘은 괜찮아 화분 등등  처럼 신나는 노래도 너무 좋아서 그 해 여름에는 계속 그것만 들었어요 노래 실력은 말할 것도 없구요 앞으로도 계속 좋은 노래 많이 들려주셨으면 좋겠습니다 늘 응원하겠습니다',
#  '세정아 정말 여태까지 세정이가 불러준 커버곡 중 최고야 어쩜 이렇게 점점 더 잘 하는지 ',
#  '그냥 이 노래를 좋아하는 한 사람이었는데 사실 그냥 지나가다 본 영상이었는데 마지막에 나오는 글에 역시 김세정 당신은 참 멋진 사람이라는걸 다시 느끼고 갑니다열심히 불러줘서 고마워요 힘을 얻고 갑니당',
#  '그저 세정님의 노래 성량에 감탄하며 보다가 세정님이 쓰신 글을 보고 다른 마음으로 다시 봤어요 덕분에 너무 따뜻하게 위로받았어요특히 이렇게 웃으면 괜찮아 보였고 괜찮을 줄 알았다그리고 난 괜찮았다그렇게 나는 내가 내 속을 들여다보지 못했다 이부분에 나도 은연중에 느꼈던 하지만 보려고 하지 않아 묻어뒀던 텅빈 마음을 위로 받았어요다시 한번 단단하도록 도와주셔서 감사해요',
#  '와 보통 커버는 원곡 못따라가는데 원곡만큼 개좋아 세정언니가 짱이다',
#  '노래 연습하던 영상이랑 완곡하는 영상을 같이 올려주시니 얼마나 노력하는지 더 잘보여서 좋습니다 세정양이 했던 말씀처럼 언제나 꽃길만 걸으시길 ',
#  '와 시작부터 훅들어오는 목소리 너무 좋다 드디어 각잡고 부르는 아나바다 완곡',
#  '아이유 아나바 커버곡 중 최고 프로는 다르다',
#  '와우 와우 세정씨 대단해요원래 울 징짱 켄텐츠 빼고는 댓글 진짜 안쓰는데이건 진짜 감동이네요 아이유 팬인 저희도 이리 좋은데 본인은 얼마나 좋아할까항상 활력에너지 뿜뿜 세정씨언젠가 팔레트에서도 꼭꼭 같이 보는 날을 기대합니다',
#  '앝 이거 제가 조아하는 노래인데 김세정님이 불러주시네여',
#  '이 노래를 부르는 것 자체도 쉽지 않은데 커버해서 영상으로 업로드하고 거기에 더불어 완벽하게 자신의 스타일로 소화해내다니 정말 대단합니다 세정님',
#  '이곡을 커버하디니 역시 갓세정 최고다 최고',
#  '대박 예전에 브이앱에서 이 노래 부르는 거 봤었는데 그때도 잘부른다고 생각했었는데 이제는 진짜 원곡만큼 감정이 고스란히 전달됨 원래도 잘 부르지만 꾸준히 노력하고 연구해서 끊임없이 발전하는 것 같아서 너무 멋지다 얼마나 많이 연구하고 연습했는지 느껴짐',
#  '드디어 아이유님 노래 커버해줬다 저번에 시간의 바깥도 불러줬는데 이번도 레전드 하나 만들어따 역시 믿듣세 아이유님 이 영상 꼭 보세요 진짜 울세정언니는 진정한 유애나라구여 흑흑',
#  '아무리 바빠도 하루에 한번씩 꼭 들으러 와요 언니 항상 사랑해요',
#  '내가 본 아나바다 커버중에 최고다',
#  ' 에서 짧은 영상보고 바로 유튜브로 달려왔어요 완곡하신 것도 너무 좋네요 좋은노래 너무 좋은 목소리로 불러주셔서 감사해요 노래 부르시는 것에 반한거 같아요 언니 노래부르는 걸로 힘들었던 것들 다 위로 받은 느낌이에요 감사합니다',
#  '그냥 세정언니 노래같다 많은 노력을 했기에 이런 결과물이 나오는 거겠지',
#  '와 진짜 세정님 노래는 들을 때 마다 힐링되는듯',
#  '연습해서 올려준다더니 약속 지켜줬네요 정말 세정 만의 음색과 감성을 느낄 수 있었어요',
#  '아 이래서 요근래 회사 가신거구나 언제나 응원합니다 갓세정 화이팅 ',
#  '아름답다 꼭 세정님을 위한 노래같아',
#  ' 뒷 부분에 적어나가는 글하나하나 곱씹어 읽어보고 싶어서 멈춰가면서 읽었습니다과거의 내가 그 시기에 열심히 살아줬기에 지금의 내가 있다는 것에다시 한번 감사함을 느끼고 가는 시간이였던 것 같습니다감사합니다 ',
#  '원곡과 비슷하면서도 다른느낌그냥 세정누나의 색깔로 잘 커버한듯',
#  '세정 누나 실력 미쳤다',
#  '세정님 프듀때부터 진짜 노래 너무 잘하셔서 팬이였는데 점점더 잘하시는 것 같아요',
#  '각잡고 부르니 장난아니네 세정쓰 바다 감미롭고 웅장하구나',
#  '세정이 노래 다 좋아하는데 역대급 커버다 목소리 너무 좋아 늘 응원해 ',
#  '나는 개인적으로 진심 아이유랑 세정이랑 같이 아이와 나의 바다 부르면 끝장날듯',
#  '        오와',
#  '정말 좋아서 여러번 듣고 있는데 들을때마다 새롭네',
#  '김세정 못 부르는 노래 없다 너무 잘한다 진짜',
#  '한글자 한글자 정성을 다해서 부르시는 느낌 넘 좋다',
#  '헐 세정아 넘 잘하자나',
#  '듣는 내내 소름 너무 잘하세요 세정님',
#  '감정이 진짜 좋다',
#  '아이와 나의 바다 커버 중 최고다 세정언니 목소리 너무 예뻐요',
#  '울림이 느껴진다',
#  '목소리랑 너무 잘어울려요 감미로와',
#  '뭐야 왤케 잘해 아 김세정 표 아나바다 음원 따서 매일 듣고 싶다',
#  '김세정 특유의 목소리가 너무 좋아',
#  '세정 언니 목소리로 여러 노래 들려줘서 고마워용',
#  '와 이거 진짜 몇번 보는지 모르겠어 아나바다 커버곡들중에 일 최고다 진짜로',
#  '허어 제가 제일 좋아하는 노래들 중 하나인데 세정님 음색하고도 너무 잘 어울려요',
#  '첫 소절 듣자마자 그냥 덜컹 했어요 평생 노래해줘요',
#  '많은 아나바다 커버를 봐왔는데 최고',
#  '노래를 이렇게 잘했다니',
#  '이노래 처음듣는데 진짜좋다 위로되고 마음이 안정되는 느낌겨우 내가되려고 이렇게 열심히사는게 안타깝고 눈물난다',
#  '노래하는 모습이 예쁘네요 아이유의 노래가 바다가 생각난다면 김세정의 노래는 숲이 더 연상되요',
#  '이러니 세정이를 안좋아할수가 ',
#  '커버해주셔서 감사합니다세정님 항상 건강하시고 롱런하세요',
#  '내가 본 아나바다 커버중에 젤 좋네',
#  '들으면서 위로받았어 세정아',
#  '완성된 보컬이다',
#  '와 언니 언니 음색 무슨일미쳤다',
#  '김세정 너무 좋아 목소리 너무 조와 소리가 듣기가 편안함이 마치 시몬스와 같다',
#  '여행스케치 별이진다네 성시경 태양계 같은 아련한곡들도 잘하실듯',
#  '언니 목소리 너무 좋아요 ',
#  '노래도 당연하지만 이렇게 깔끔하게 부를일누나 나죽어',
#  '진짜 처음부터 지금까지 남다른 아티스트',
#  '김세정님정말정말로노래를부르고예쁘네요 ',
#  '커버중에서 최고다',
#  '언니가 뷔앱에서 불러주던거 너무 좋았는데 오피셜 뜨니 이렇게 행복할수가 없어요 오늘 고향 내려가신거 같던데 좋은 시간 보내다 오세요 사랑해요 김세정',
#  '저렇게 본인 목소리가 좋고 노래도 잘 부를 수 있다면 무슨 기분일까',
#  '역시 갓세정',
#  '시원시원하니 듣기 진짜 좋습니다 덕분에 위로 받고 가요 영원히 세정세정해',
#  '이 노래 너무 좋아 진짜 아이와 나의 바다 아이유버전 마크툽 버전 김세정 버전 이 개만 계속 돌리는 중',
#  '진짜 노력형 연예인의 표본첨에 커버한 영상보다 각잡고 커버한게 훨씬 깔끔하고 발성연습 많이 한듯',
#  '세정언니 노래만 들으면 눈물이 나요',
#  '그냥 소름돋았어요 노래해주셔서 감사합니다',
#  '목소리가 너무 좋으셔요',
#  '잔잔한노래도 좋지만이젠   처럼 신나는 노래 내주세요구냥 모든장르를 다듣고 싶지만그건 넘 큰 바램인것 같아서요 그냥 저의 의견일 뿐입니다 커버 넘 멋져요 ',
#  '갓세정 느무 좋아 ',
#  '아나바다 커버중에 최고',
#  '드디어 존버는 승리한다',
#  '너무 잘 어울리고 감동적',
#  '세정님 항상 응원합니다 좋은 노래 많이 불러주세요',
#  '세정이 진짜 인생노래 좋은거 하나 받았으면 좋겟다',
#  '와왜 날이 갈수록 더 잘해지는 것 같지 나중엔 얼마나 더 잘 부르려고',
#  '와 진짜 잘부른다',
#  '타고난 보컬이다',
#  '노래 진짜 너무 좋다',
#  '와이 노래는 함필규가 아니어도 감탄할수밖에 없다',
#  '들으면 울컥하는 감정을 느끼게 하는 보컬과 같은 시간에 존재하고 있어 기쁩니다',
#  '마음이 깨끗해지는거 같아요목소리가 진짜 너무 이쁘세요',
#  '와 진짜잘한다 소름',
#  '완벽한 노래였어 세정아',
#  '연습 엄청 하시던데 노래가 너무 좋아서 꼭 세정누님 버전으로 듣고싶었는데 감사해요 ',
#  '진짜 너무 좋아 세정 짱 사랑헤',
#  '저절로 눈감고 경청하게 되네완전 선물같은 노래 그저 감사',
#  '많이 감싸주고 싶은 사람 좋은 노래 잘 듣고 갑니다',
#  '이 노래는 더 이상 나아질 수 없다고 생각했을 때요 대단해요',
#  '와 너무 잘부른다 이 언니 못하는게 뭐여',
#  '목소리 미쳤다 미쳤어',
#  '목소리가 진짜 좋다옥구슬같아 반짝반짝 빛나는 것 같아흥해랏',
#  '진짜 너무 잘 부른다 ',
#  '목소리는 아름다워요 정말 너무 좋아요',
#  '완전 좋아 세정 언니 사랑해요 ',
#  '어떤일이든 열심히 하는 모습이 참 예쁜듯',
#  '와치유되는 목소리예요 진짜',
#  '예전부터 아이유님 곡 연습하시고 분석하셔서 마스터 하실 것 같았는데 예전보다 훨씬 는 거 보니 노력한 게 보여요 화이팅',
#  '목소리 너무 좋아요노래에 잘 어울리시는듯',
#  '와 진짜 가수는 다르구나',
#  '목소리 너무 뷰티풀 ',
#  '하 세정 최고야 사랑해 울세정',
#  '아니 개잘하네 강약조절 미쳤구나 이걸 이제야 봤다니 ',
#  '세정누나 영상 많이올려주세요 세정누나 화이팅',
#  '원래 커버곡이 원곡과 느낌이 너무 달라서 잘 안 들어요 물론 사람이 다르니까 느낌이 다른 건 당연하지만 그 곡의 감성이 너무 차이가 나서 커버곡을 잘 못 듣는데 이거는 들으면서 소름이 돋기도 하고 너무 좋다 하면서 들었습니다',
#  '아니 야 아니 뭐야 진짜 와 진짜 너무 큰 감동 받았는데 진짜 노래를 왜이렇게 잘불로 진짜 표현할수가 없네 와 진짜 뒤지게 잘부른다 가성이랑 진성 연결을 어떻게 저렇게 잘하지 진짜 킹세정 하',
#  '음색이 찰떡입니다 니노래 내노래 시전중이시네요 진짜 잘 어울립니다',
#  '와그냥 와라는 말밖에 나오지 않는다',
#  '언니진짜 노래 너무 잘어울려요 이런 커버 자주 올려주세요 ',
#  '멋지다 세정',
#  '어떻게 감정이입이 되게 노래를 부르는거지',
#  '목소리가 참 좋다',
#  ' 아빠패드 와 미춋다리 세정언니 개이뽀 목소리도 겁나 조아 구독 박고 간다',
#  '와 진짜 좋다 진짜',
#  '언니 제발 코로나 끝나고 콘서트 열어줘요 ',
#  '개좋다',
#  '오 잘한다 우리세정이',
#  '너무 이쁘다노래도 가사도 음색도 얼굴도 그리고 영상 후반 글들에 담겨진 그 마음까지도',
#  '아무생각없이 들었는데 눈물난다 원래 댓글 잘 안다는데 이건 안달수가없었다 평소에 세정님 좋아했는데 이 곡으로 더 좋아졌어요 다음 커버도 기대할게요 좋은 목소리 들려주셔서 감사합니당',
#  '진짜 위로받고 가요',
#  '세정언니 진짜로 사랑해여 언니 신곡 잘듣고 있어여 언니 나 증말 언니때매 사망해여',
#  '미쳤다 진짜 너무 좋다',
#  '중간중간 숨 쉬는 소리가 많이 줄어든 것 같아요 전에도 좋았지만 듣기 더 편해진 느낌이라 더 좋네용 발전하는 모습 멋있어용',
#  '위로해줘서 고마워 세정아',
#  '재능과 노력이 만나면 이렇게 되는구나',
#  '노래 너무 좋아요',
#  '역시 갓세정 ',
#  '몇몇 연예인만 가지고 있는 느낌이 남맘 놓고 덕질해도 불안하지 않은 타입',
#  '노래부를때 제스처가 예쁘네요',
#  '이게 라이브라면 아이유보다 나은 것 같다 아이유의 완곡 라이브는 아직 못 들어 봤으니까',
#  '세정이역시최고',
#  '세정누나 너무 예쁘세요 그리고 경이로운소문 세정님출연헤서 꾸준이 받엇어요 세정누나 늘어지지말고 지금그대로 건강해주세요 저는 죽을때까지 세정누나 팬팬팬팬 중에 찐찐찐찐팬',
#  '세정이는 진짜 진짜다 어쩌면 이렇게 발전하는게 눈에 보일까 목소리고 노래고 최고야 세정아',
#  '너의 목소리를 들으면 눈물이 흘러',
#  '그래 기다리고 있었음 넘나 좋넹 ',
#  '이 어려운노래를',
#  '와 진짜 개잘해',
#  '중요한 시험을 치르고 제대로 놀았다는 기분을 내고싶은 마음에 공연 몇일 전에 즉흥으로 예매해서 인생 첫 뮤지컬을 세정님 공연으로 봤어요그리고 세정님 연기에 노래에 감동받아 몇번을 울고나왔는지 너무 잘하세요 진짜인스타팔로우하고 공연하시면 찾아가보는 정도로 덕질해보려고요 이번 커버도 진짜 넘 좋습니다 ',
#  '소름끼치게 클린하다',
#  '소화력 미쳤',
#  '황민현이랑 목소리 잘 어울릴 것 같아욥 아무 관계는 없지만 언젠가 듀엣 소취해봅니닷 ',
#  '세상에 아이유 보다 못할줄 알았는데완전 대박이다 각자에 매력이 있다',
#  '세정님 지나가다 들린 유애나는 감동받아 울면서 들어요 감사합니다',
#  '세정아 잘했어 그리고 고마워',
#  '너무너무절한다',
#  '세정미쳐다',
#  '아이유 찐팬 감사해요 커버해주셔서',
#  '김세정 씨의 노래를 들으면 마음이 편해집니다 ',
#  '울지마 언니 사랑해',
#  '복가왕 한바탕웃음으로 듣고 그때 깜놀 그때부터 팬임 이선희 노래 제대로 부른 가수 그때 첨봤음아이유 역시 독보적 음색인데 역시 세정님 잘 부르시네요 항상 응원할게요',
#  '와 진짜 너무 좋아요',
#  '이렇게 발라드를 안 지겹게 많이 듣는건 처음이네',
#  '목소리 사랑해요 김세정 필리핀에서 온 팬이에요',
#  '목소리 너무 좋아요 ',
#  '와 언니 미쳤어요 음원나왔음좋겠다 근데 왜 계속 가위바위보하나빼기해요 찌도 내주세요 ',
#  '언니 생일축하해요',
#  '너무 잘 한다 세정아',
#  '가수는 역시 가수구나',
#  '좋아요 개이상 누르는 기능 없나 노래 진짜 너무 너무 좋다',
#  '와 진짜 잘한당',
#  '와노래 너무 좋다하고있다가가위바위보 하고있는 세정의 손을 본후로 집중이안된다젠장',
#  '무슨일 목소리 넘 좋아요',
#  '다 영어 댓글밖에 없넹세정언니 엄청 잘부르세용 언니 노래 잘듣고 있어용 힘내세여',
#  '미쳤어 소름돋아',
#  '진짜 잘했어 세정아',
#  '목소리 진짜 이쁘다',
#  '개쩐다',
#  '가사가 무엇을 의미하는건지 절절하게 맘에 닫아요 아직도 길 못 찾아 헤매고 있는데 ',
#  '이뻐요',
#  '갓세정',
#  '정말 어렵게 부르는 느낌이 있다 실력으로 인한 어려움이 아닌 넘치는 감정을 하나하나 눌러담아 어렵게 한걸음씩 나아가는 느낌 뒤로갈수록 단단해지는 느낌이 더 강해져서 너무 좋아 김세정 언제나 최고야',
#  '노래 듣다가 운 적 처음이에요',
#  '무조건인정진짜꾸준히연습하시더니이제 완전 아이유스탈 익혔네요대박',
#  '너를 그리는 시간도 불러주면 좋겠다',
#  '결국 왼손에게 이기지못한 오른손 ',
#  '마음을 울린다',
#  '언니 진짜 사랑해',
#  '노래도 노래지만 가위바위보는 왼손으로 하시는 편이 좋겠어요',
#  '너무 좋다 노래 많이 커버해주세요 ',
#  '좋은 노래 좋게 잘 들었어요',
#  '원곡보다 더좋음',
#  '언니의 감정이 그대로 보이는 노래라 더 좋네요 마음에 와닿은 언니 목소리',
#  '세정언니는 역시 노래파야',
#  '울면서 소름 돋는 다는 말 알아 아이유가 부르는 이 노래가 처음이었고 지금이 두번째다',
#  '천사 ',
#  '세정이짱',
#  '진짜 잘하네',
#  '김세정 누나 알라뷰 ',
#  '아 너무 좋아',
#  '너무 좋다',
#  '어떻게 이렇게 진성가성 반가성 조절을 잘하지',
#  '누나 사랑해요 ',
#  '시간 들었는데도 안질리네 참',
#  '믿듣 갓세정',
#  '으으어어 세정언니 이쁘댜아아',
#  ' 역대급',
#  '커버 좋아요',
#  '잘불러요 몸매도 이쁘고 얼굴도 이뿐데 노래까지잘 불르시다니 사랑해요',
#  '아이유씨것도 좋지만 전 세정씨 노래가 더 소름돋네요',
#  '아이유 라이브로도 듣고싶다',
#  '나중에 아이유 김세정 콜라보 했으면 좋겠다',
#  '세정 못하는 게 뭐야',
#  '나 선정 세상에서 노래 젤 잘부르는 가수',
#  '경소에서 모습만 생각나서 먼가 조금 어색하지만 넘 이쁘네요 근손실은 잘 극복하셨나요',
#  '오우 김세정 너무 잘한다 역시 김세정이야 너가 너무 잘됫으면 좋겟어',
#  '와진짜감탄만나온다',
#  '유튜브에서만 보는게 아까운 정도인데',
#  '갓세정',
#  '노래가 가사가 빠져들게 만드네요',
#  '당신은 너무 귀엽다 ',
#  '이거 멜론에 나왔으면 좋겠다',
#  '아이유 노래 들으면서 이 노래 불러줬으면 했는데 진짜 어울린다 ',
#  '갓쎄정',
#  '왼손이 승률이 좋군요',
#  '아이 럽 유 화이팅 ',
#  '김세정 화이팅',
#  '와나울었어',
#  ' 이부분 커버영상 중에 아이유랑 젤 똑같이 하는사람 발견',
#  '춤 관련 영상 찍으면 엄청 인기 많을 듯',
#  '멋져요 언니',
#  '눈빛에 치였고 목소리에 기억을 잃었습니다',
#  '목소리가 너무 맛있다 ',
#  '미쳤다 진짜',
#  '이불 없이 헐벗고 잤을때 그 순수함이란그런 음색',
#  '아 먹먹해지네 진짜',
#  '와 최애곡을',
#  '왼손이 계속 이기고 있네여',
#  '내 최애곡을 내 최애가수가',
#  '언니 최고',
#  '오우오우 소름',
#  '너모 아름답다 이거 보구 구독 갑니덩',
#  '왼손 보자기 오른손 주먹 왼손 승',
#  '와씨 세정아 삼촌 또 여기서 지리고 간다',
#  '벤님이 보인다 들린다 ',
#  '진짜 궁금해서 그러는데 못하는게 뭐세요',
#  '힐링 보이스',
#  '김세정 너무 소즁해',
#  '유애나 답닼',
#  '엄청나다',
#  '감정 부분만 좀 더 잘 하면 될듯 라이브 중에선 이거 뛰어넘은 게 없는듯',
#  '노래도 잘 부르시는데 치아가 굉장히 예쁘시다',
#  '감정부분이 뭐가 부족함 ',
#  '오올 떼정이 좀 부르네',
#  '이 노래는 세정이 어렸을 때 자신을 너무 혹독하게 대했기 때문에 지금의 자신에게 하지 말아야 한다는 것을 일깨워주는 곡이다 그녀는 때때로 연약해져도 괜찮다는 것을 스스로에게 상기시키고 싶었다 앞으로 그녀는 자신이 힘든 시간을 보내고 있다고 사람들에게 말할 수 있도록 해야 한다 바다가 그녀를 위로해 주었고 그녀는 그것에 감사해한다 이 커버를 만들겠다는 그녀의 의도는 너무 순수해서 들을 때마다 눈물이 날 것 같아요 세정 씨 잘 컸어요 사랑해요',
#  '이 노래가 시라면 부분은 수필 같아요',
#  '오른속 살짞 쥔거 왤케 기엽나요',
#  '역시 아이유 찐팬 답네요 ',
#  '정말 더할 나위 없었다',
#  '이 댓글은  님의 댓글을 번역본을 붙여 쓰기 한 것입니다 참고 하세요 ',
#  '세정실력지리지는 결국 안쓰기로 한건가',
#  '어머나 세상에',
#  '뮤지컬하면좋겟다',
#  '언니 사랑해요 ',
#  '사랑해눈나',
#  '눈이 참 아름다운 김세정',
#  '하시는데염',
#  '몰랏네요 알려줘서 고마워여',
#  '얼굴도 이뻐 노래도 잘해 연기도 잘해 갓세정 최고에요',
#  '아 가위바위보 한다는 댓글보고나서부터 집중이안됨',
#  '저도 아나바다 처음 들었을 때 큰 진심이 담긴 가사에 목소리에 마음이 너무 벅찼어요 벅차서 너무 행복하기도 슬프기도 했어요커버영상에 언니 목소리와 표정 마지막에 마음 꾹꾹 눌러담은 편지까지 김세정이라는 사람의 노력과 진심이 느껴져서 그 모습과 마음이 너무 예뻐보였어요 얼마나 노력했을까 가늠조차 안되지만 언니의 소중한 목소리와 그 예쁜 마음 덕분에 행복했습니다 김세정의 바다는 더 자유롭고 더 행복하길 바라고 저도 여기 이 자리에서 응원할게요 세정님 세정언니 고마워요고맙습니다',
#  '아이유가 부른 아나바다는 뮤지컬 같았는데 세정이 부른 아나바다는 영화 같아 골라들을 맛이 난다',
#  '와 아이유노랠 김세정이',
#  '와우 지금까지 들어본 아이유 커버중 최고인것 같아요 여기서 세정의 목소리는 아이유님과 다소 비슷하다 세정언니 목소리 너무 좋다 번역기만 사용하기 때문에 문법이 틀렸다면 죄송합니다',
#  '매일 매일 듣고있어요 너무 좋아요 묵찌빠',
#  '어머억언니성대에 꿀발랐어 어머',
#  '오랜만에 여자김세정버전 노래군',
#  '크으러나 ',
#  '태극무희 엄지원님 노래도 잘하시네요',
#  '임마 삼촌 또 와따',
#  '기다렸다구',
#  '더 늘은거같아 좋다',
#  '세정쓰 럽쏘마치예요',
#  '왜 구독자가 이거 밖에 없을까',
#  '믿듣 세정',
#  '남자 버전도 듣고싶다',
#  '왼손 승',
#  '김세정 난 너의 열혈팬이야',
#  '확실히 입이 커서 그런가 딕션 딱딱 붙는 거 보소 히야',
#  '피부가 하얀디 흰옷이라 백설기잉줄',
#  '싫어요 누른 명은 뭐 땜에 누른 건지 궁금하네',
#  '프리티',
#  '오피셜 떳다',
#  '왼손 승',
#  '윤하 바다아이 가능한가요 ',
#  '진짜',
#  '대바아',
#  '          김세정 리메이크 앨범 오늘육시 김세정   세정          ',
#  '이야',
#  '언니',
#  '조보아씨 내려와서 좀 들어봐유',
#  '이런 노래 내거나 이 노래 음원으로 못듣나 세정   로 해서',
#  '와',
#  '많이 늘었네요',
#  '와',
#  '언니',
#  '          아이와 나의 바다',
#  '늘 발전하는 좋은 가수가 되어주어서 고마워요',
#  '아이유님이 빨리 언급해 주시길 바랍니다',
#  '인정',
#  '와 진짜 세정이를 사랑할수밖에 없는 가창력이다 명가수가 부른 명곡에 명가수가 커버를 원곡보다 개인적으로 좋다고 느낀건 처음이네 사랑해',
#  '오베리굿이다',
#  '디즈니 같다',
#  '감정봐',
#  '김세정 노래 진짜 잘부르네',
#  '세정이와 지은누나의 듀엣 기대해봐도 되겠죠 우리 세정이 너무너무 이쁘다 사랑해 ',
#  ' 이부분은 어쩌면 세정이 우리세상들 생각하면서 불렀을거같다 ',
#  '진짜 이노랠 얼마나 연습하고 이해했는지 느껴진다 노래 너무 좋아요',
#  '와 언니 뭔가 다른 느낌이에요 그 감정이 느껴지는 데 감동',
#  '위에 작게 클린버전이라니 넘나 귀여운 세정하지만 귀엽지 않고 카리스마넘치는 노래실력',
#  '역시 갓세정',
#  '세정이 목소리만 들어도 이미 힐링이네 너무 좋아',
#  '고음 진짜 대단하시다 어케 저런 고음이 나오는 것일까  ',
#  '김세정의 노래는 사람의 감정을 어루만지는 노래',
#  '진짜 와 진짜 갓세정 ',
#  '세종대왕님 생일이 얼마남지않아서 다시봐도 세종대 사랑해 ',
#  '세정실력지리지 역시 김세정 너무잘한다',
#  '사랑해요 갓세정',
#  '이게 내 아이돌이지',
#  '이 노래 꼭 세정 목소리로 듣고싶었는데 너무 좋아요 팔레트에 출연하는 꼭 날이 오길',
#  '다음주 번째 레드북 갑니다 그전에 다른 노래들로 또 기대감을 증폭',
#  '발음 진짜 좋다',
#  '저도 유애나이지만 이번 커버 미쳤네여 ',
#  '누나 너무 잘불러요 역시 김세정 ',
#  '미모도 실력도 감성도 다 좋아졌네',
#  '와 미쳤다',
#  '잘했어 잘불렀어 넘좋아아 계속 보고있엉 헤헤히히',
#  '이게 어떻게 그냥 노래야 너무 좋자나',
#  '세정쓰 사랑합니다',
#  '마지막에 나오는 글 읽고 눈물 줄줄',
#  '역시 세정이다 감성이 정말조와 영원히 너의 세상이 되고싶군아세정과 세상의 바다이지금님의 인스타에 올라오지않을까 살짝쿵 기대도 해보며 ',
#  '와 너무 좋다',
#  '연기면 연기 노래면 노래 예능이면 예능 힘이면 힘 진짜 재능러인데 사람들이 더 많이 알아줬으면',
#  '김세정 짱',
#  '세상은 그렇게 모든 순간내게로 와 눈부신 선물이 되고',
#  '아 너무좋아요 어쩜 점점 더 깊어지고 넓어지는지 넘 자랑스러워여체고체고',
#  '언니 잘 했어요 세정 언니 짱',
#  '떡상 각이다 미쳤다 진짜',
#  '언니 대박',
#  '머쿠버버야더너커토 누나 너무 이뻐어오요뇨',
#  '헐 와 대박',
#  '너무 좋아요 사랑해요',
#  '싫어요 누른 사람 누구냐내가 찾아 간다새정누나',
#  '갈수록 노래실력이 크으',
#  '정말 좋게 듣고있던 노래인데 또 커버를 감사합니다',
#  '듣다가 고막이 녹아 내린거 같은데 이거 어떡하쬬',
#  '허억 미쳤어 진짜 아나바다',
#  '항상 응원합니다',
#  '세정아 이 할미 소름 돋았다 너무 잘불러 ',
#  '되게 깊은 바다 속에 혼자있다 빛을 따라 헤엄쳐 나와서 태어나 처음 접해보는 세상이랄까초반은 먹먹했는데 뒤에서 되게 웅장해지는 것 같아요 원래 레드북 보려고 서울 갈려했는데 망할 코로나 때문에',
#  '진짜 미쳤다 너무 좋아 ',
#  '진짜 노래 잘부른다',
#  '미쳤어요드디어목소리진짜너무좋아요 ',
#  '        ',
#  '진짜 넘 좋아요 아나바다 커버라닠 라이브에서도 많이 연습하던뎅 이렇게 진화 하다닝',
#  '듣다가 고막 녹았어 언니 ',
#  '듣다가 눈물 난다 ',
#  '와 그 어떤 커버 영상보다 젤 좋아요',
#  '헐 와 갓세정',
#  '역시 갓세정',
#  '세정언니 화이팅 세상들이 응원해줄께요 ',
#  '누나 팬 되기전까지  이 뭔뜻이었는지 몰랐던 사람',
#  '와 언니 진짜 멋있어요 ',
#  '아이유님은 확 끌어오는 목소리가 있고 세정님은 청량한것 같애요',
#  '미쳤다',
#  '이건 진심 맘에 울림이 오네요',
#  '목소리에 아주 녹는다',
#  '이건 진심이다',
#  '아 이제 콘서트때 라이브 들으면 죽어도 여한이없',
#  '오늘하루에 피곤이 사라지는 느낌이다',
#  '내가 바라던 소원 하나가 이루어졌다',
#  '진짜감정잘살린다',
#  '세정아 너무 좋다',
#  '아름답다',
#  '아우 눈물이 흐른다',
#  '소름 짱이야',
#  '이 사람의 한계는 어디일까',
#  '귀호강하고 갑니당 ',
#  '아 사랑해요 세정의 아나바 드디어',
#  '세정이 팔레트나올때됐다',
#  '너무좋다 와 밖에 안나옴',
#  '아 커버곡 하려고 최근에 회사를 많이 가셨던 거군요',
#  '와 얼마나 연습했을까',
#  '언니 너무 좋아요 ',
#  '아니나 이거 올라온줄 방금 을아써 진짜 대박이다 왜 인터뷰영상만 왜 올라오지 커버는 안올려주나 이랬는데 여기 있네',
#  '이쁘다 울언니 ',
#  '아이유님이가 이 영상은 봤으면 좋겠다',
#  '누나',
#  '조회수야 좀 올라가봐',
#  '미쳤다',
#  '드디어 아이와 나의 바다 커버 영상 올리셨네요 가사와 목소리가 너무 좋아요 특히 고음부분이요 고음이 진짜 어둠을 뚫고 빛으로 날아가는 것 같네요 소름 쫙 끼치네요 노래를 부르는 누나의 마음이 여기까지 느껴집니다아이유님 노래 뺏아가겠는데요',
#  '사랑해요',
#  ' 부터 숨죽여 듣기',
#  '대박',
#  '아미쳤다 존버성공이요',
#  '어머어머아나바다라니지은언니 인스타 스토리에 꼭 올라왔으면 좋겠어요이미 세정님이라면 음색이며 실력이 좋다는건 알고 있었지만 이 노래를 통해 세정님 목소리가 이쁘고 실력도 좋다고 더 멀리 멀리 바다를 타고 알려지길 바래용와고음이 이렇게 깔끔하게 나오다니대박이다',
#  '와 너무 좋아       ',
#  '세정아 뭐야울었어',
#  '드디어 목소리 완전 좋아',
#  '미쳣나봐어떡해',
#  '노래연습 진짜 많이 했나보네소리가 달라졌다',
#  '세정아',
#  '미쳤다',
#  '그리고 스물다섯스물하나도 녹음해서 올려주면 좋겟다음질좋게듣고싶어 나는 복면가왕에서 처음 노래들었던 그 소름을 잊지못해 진짜대박이었어',
#  '와 마지막고음에서 내 심박수',
#  '와대박이다',
#  '오늘 월일 세정님 생일이라고 합니다생일축하해요',
#  '왜 늦게 왔냐아앙',
#  '사랑해 세정아',
#  '예뻐요 악 세정 언니 재일 이뻐요',
#  ' 언니 울지마요',
#  '  세정',
#  '한국인 찾습니다',
#  '뭔가 음색이 바뀐것 같아',
#  '아이유님 오시길제발',
#  '  세정           김세정',
#  '여기 미국 유튜버 댓글창인가 한국 사람 한명만 올라갑시다',
#  '한사람의 목소리가 아닌거 같아요',
#  '마지막 나오는 글은 누가 적은 건가요',
#  '세정이요',
#  '하나 빼기',
#  '누나 나듀겅',
#  '끝에 글 세정님이 쓰신건가요',
#  '이 영상 징니인스타에 올라갔나유',
#  ' 왼손이 이기셨어요',
#  '노래가 어려워서 긴장해서 부르는게 보이네',
#  '초',
#  '나 일등 너무 좋타',
#  '세정눈나 헤으으응',
#  '엄청 연습하고 노력한 게 보이고 너무 잘 불러서 멋있고 좋았어요 다만 개인적으로 아쉬웠던 건 뭔가 노래에 담겨야 할 감정과 울림이 잘 느껴지지 않고 그냥 잘 불렀다 는 느낌만 있는 것 같아요 그래도 김세정님 앞으로 진짜 좋은 가수가 되리라 믿고 있어요 응원합니다',
#  '세정',
#  '아이와',
#  '너무 듣기좋은데 손이 너무 거슬림',
#  '아직 호흡이 얕아서 좀 조이는 감이 있네요 발음을 더 깊게 해보세요',
#  '진짜 열심히 한디 진짜 최선을 다하는 군요 디테일에서 떨어지지만 ',
#  '가수한테 훈수 두는 거 개웃기네',
#  '솔직히 태연  커버 했을땐 너무 별로라서 비판하는 댓글 달았었는데 몇 년 지나고 지금 이 아이유 노래도 별로겠지하는 생각에 들어와봤는데 엄청나게 발전했네요',
#  '에코 좀 빼주세요 ',
#  '난 원곡에 아이와 나의 바다가 더 좋다',
#  '스피커 설정을 바꿔보세요 지금 이노래는 다른 커버에 비해 에코가 없어요',
#  '뭐야 너무 어이없는 댓글이라 뒷통수 땡기네',
#  '하하 원곡이 좋다고 하면 될걸 아이유님 버전이라니 마치 아이유님이 원곡자가 아닌거 같은 표현이네요',
#  '     앗 죄송합니다 수정하겠습니다',
#  '굳이 여기에다가 이런 댓글 다는 이유가 뭐지 님 들으라고 세정님이 커버 하신 것도 아니고 커버에 조건이 있는 것도 아닌데 세정님 커버 마음에 드는 사람으로서도 기분이 나쁜 댓글인데 세정님이 보시면 얼마나 속상하실지참 본인만 생각하는 쓸모없는 댓글이네',
#  ' 바지락해물칼국수 제 생각을 말한건데 왜 님이 발끈하심',
#  '원곡이 더 좋은건 당연한거라 보통 적지 않죠바보같은 댓글',
#  '     다른 사람들에 생각은 다를수 있다고 생각안함이게 더 바보같은 댓인듯',
#  '이번주 쫑이 병아리다 완전신이 주신 선물 이신',
#  '우리 늉이들 노는게 젤 재미있징그와중에 우리 민현이 젤리 반지 계속 끼고 있어 ',
#  '왜 그들은 모두 그렇게 재미있고 귀여운가요 나는 그들이 게임을 하는 것을 보면서 너무 웃어요    를 보면서 정말 힐링하는 시간이었어요 모든 뉴이스트 멤버 들에게 너무 감사해요 사랑해요',
#  '진짜 누구보다 못하지만 게임에 진심인 사람들이라구 ',
#  '신이 사랑한 아이 김캐리 오늘도 귀엽쫑 웃기쫑종현이 입술색 잘못보던 색인데 예쁘다 ',
#  '나도 럽스때매 한주 살아요 뉴동과 함께하는 시간 너무 행복해',
#  '앜 아 귀여워 우리늉이들 그냥 보드게임만 해도 이렇게 귀엽고 사랑스러울 수가 다같이 있는 늉이 젤 좋아',
#  '민현이 저머리 보니 년도 생각나네 잘생겼다 곱다고와',
#  '아 너무 귀여우어어어어어 보고싶다 실제로 보면 더 귀여울곤데 말이지',
#  '민현이 웃음 소리 넘 귀여워',
#  '이야증말 재밌어보인데이 게임 계속 지면 열등감 스트레스   ',
#  '그칰 상어는 코때려야짘 헐랭한데 어디서 보고 들은건 많은 민현잌귀여웤',
#  '뉴이스트 게임 실력 모 아니면 도다갑자기 잘하다가 갑자기 못하고마지막엔 결국 늉망진창 ',
#  '쫄보스트 넘무 귀여워',
#  '뉴이스트 귀여워',
#  '김종현 병아리같아 귀여워',
#  '개웃긴다 눈물남',
#  '귀여워 사랑해',
#  '상어코때리기 ',
#  '꿀잼 애들끼리 뽀짝뽀짝 노는 모습만 봐도 힐링된다',
#  '프리한 늉이들 제일사랑함',
#  '사랑해 ',
#  '뉴이스트 ',
#  '아론님 품에서 나온 칸쵸 감동적인 인성즈',
#  '귀여워 진짜',
#  ' 육성으로 소리내서 웃음',
#  '와따 진짜 빨리 끝나네',
#  '초등학생 같기도 하고 그냥 자기들끼리 잘 노는 강아지들 같아',
#  '짐캐리',
#  '게임 조금이라도 잘하는게 있는게 어디야',
#  '우리 늉이들 모여서 다같이 알콩이 달콩이 노는것 넘 좋은것 그냥 애들 끼리 맛난거 먹고 시간같이 보내는것만 봐도 미소가힐링컨텐츠 근데 재미도 있어 얼음깨깈아진짜안웃긴게 없엌 쿠키까지 늉망진창진짜 존잼',
#  '아이구 귀여워들 ',
#  '우리 뉴이스트',
#  '뭐했길래 다들 비즈 목걸이팔찌 하고있는거야',
#  '다 잘생겼다',
#  ' 아 상어한테 물린거 개웃곀',
#  '역시 럽스 인성즈도 보고 겜하는 늉이도 보고',
#  '꺅그룹파이브',
#  '이번 럽스 황민현 왜케 호락호락하지 않은 바보같냐 특히 상어 코 때리는 부분 표정 찐임 졸라 욱겨',
#  '우리늉 드디어 잘하는 거 찾았나 했더니제대로 안한 거였어',
#  '진짜 재미있다',
#  '보고싶어',
#  '오늘도 우리쫑이 귀여워',
#  '게임들이 아기자기 애들같네 귀엽다 아악 퀴즈 틀렸다 아니다 맞춘건가',
#  '아이돌한테 온갖 게임을 다 시키는 케이팝계에서 십 년을 활동했는뎈',
#  '진짜너무귀야우엉 머리깨',
#  '일주일을 어떻게 또 기다리나요',
#  '아 귀여웤',
#  '개웃겨 쿠키영상 뭐야',
#  '아아아아앙 제일 귀여워',
#  '대본없는 뉴이스트 최고 늉망진창이지만 다 즐거우니까 그걸로 충분해',
#  '주사위와 풍선과 티격태격 로니레니가 너무 웃긴 힐링컨텐츠 러브스토리',
#  ' 아로니의 어쩐지 잘한다했다가 너무',
#  '세상 사람들 다 뉴이스트 하면 좋겠다',
#  '늉망진창 겜못늉근데 왜이렇게 재밋는거냐곸 피날레까지 완벽',
#  '진짜 가뒀구나 감사합니다 제작진분들 너무 자밌다 역시 다섯이서 노는것만봐도 잼써',
#  '드디어 드디어',
#  '늉망진창도 사랑해',
#  '귀엽다',
#  '사랑스런 우리 늉이들',
#  '보드게임과 함께하는 뉴이스트 너무 좋아요 늉망진창 ',
#  '매금요일 와주셔서 고마워 뉴이스트는 진짜 내 행복의 원천니다     사랑해 울늉이들     ',
#  '상어 코 때리는 황민현 귀여워',
#  '민기 개웃기네',
#  '강동호 귀여워 ',
#  '쿠키 ',
#  '상어 때리는거봨',
#  '아론 티셔츠에서 칸쵸 꺼낼때 왜케 사람이 귀엽고 따숩지 절친의 니즈를 이렇게 챙기다니',
#  '뉴이스트 대유잼',
#  '그룹파이브 뉴이스트가 최고야',
#  '당신은 나의 미소',
#  ' 밤길 조심하랰 뭘 또 알겠댘 내 인생 개그맨 늉 ',
#  '펭귄게임 진짜 오래했어긴장감 넘친다',
#  '울배코 상어한테 물렸쪄요 우쭈쭈 호 ',
#  '정말 아주 귀엽당 진짜',
#  '동호 다 걸려귀여운 허당 아론이 스윗해',
#  '야이 초딩들앜 노는거 진짜',
#  '노랑이 김종현낚시 왜이렇게 리얼한건뎈연기천재넼',
#  '아기다 아기 아직도 아기다 개월 개월이당',
#  '우리 긔여운 맏내 아론이는 막내 민기 위해 깐쵸도 갖다주네 스윗해',
#  ' 황민현 진짜 미쳤다리 ',
#  '이상하다 한 분 본거같은데 분이 훅가있네 ',
#  '울 애들 예능에 진심이라구여 예능 마니 출연시켜주세요',
#  '뉴이스트한테 제발 게임좀 그만 시키면 안될까 더 재밌는거 많을텐데',
#  '완전 재밌고 일주일을 이거 하나 보는 낙으로 버티는데 뉴이스트끝까지 러브 옆에 있어줘',
#  '우리 렌 진짜 귀엽다표정으로 놀라는거 밍무룩한거 기분좋은거 다 표현하는중 리액션요정 아니랄까봐 아 귀여워',
#  '썸넬이 곧 오늘 럽스의 하이라이트일 것 같은 느낌',
#  '백호 다걸려게임 진짜 못해귀여워죽겐네',
#  ' 동생이 조용하랬다고 입꾹꾹 하고 있는 맏내 너무 귀여워서 심장 아픔',
#  '아니 민현아 상어 코 때리는 건 어디서 배웠어 웃겨 죽는 줄',
#  '라라',
#  '아나 황민현 상어 코때리는 거',
#  '음악 제일 잘 하니까 괜찮아 ',
#  '아 쿠키영상 개웃겨 잘하는거 찾았다고 좋아했는데 제대로 안 꽂혀있던거',
#  '럽스내 삶의 버팀목이야 ',
#  '동호 의상 오늘 왤캐 상큼하고 잘어울리냐 목걸이도 너무 귀여워',
#  '백호 기다려랰',
#  '반칙없으면 게임 못하는 애들',
#  '강동호 귀여워 ',
#  '오늘 아론이 어디가고 영민이가 왔네',
#  '아론아 오늘도 함께해줘서 너무 고마워 ',
#  ' 최민기 등에 럽스스티커 누가 붙였냐뭐 안봐도 곽아론',
#  ' 승부사 아로니 멋있어 그의 품에서 나오는 칸쵸',
#  ' 저렇게 귀엽게 놀란다고 나였으면 욕부터 나와서 인성 논란 생겼을 듯',
#  '아 밍기 개는 훌륭하다 블로킹 넘 웃곀',
#  ' 우리 아기 연기 천재인가봐요 동호야',
#  ' 팔꿈치 개웃겨재롱둥이 밍기',
#  '아론 안경에다가 모자넘 좋다 ',
#  '스페셜 비디오 감솹니다안무영상 풀버전 기대합니다 스엠 ',
#  '자컨 사랑해 에스엠 ',
#  '해체하는거 아니지 갑자기 불안하다',
#  '젭알 이대로만 쭉 해주세요 저 겨울정규 위해서 돈 모으고있으니깐젭알',
#  '제가 이제  을  하기로 했습니다    ',
#  '싸우지말고 서로 아껴주고 주변사람들에게 잘해줘라',
#  '사랑해 레드벨벳 영원하자',
#  '레벨 짱짱 너무 사랑해 오래 오래 레벨 하자',
#  '우리에게 여름은 언제나 레드벨벳이야 가을도 쭉 함께하자 사랑해',
#  '스엠 무냐 요즘 일 잘하네 이렇게 영상 올려주는 거 아주 조아 역시 내 취향 아는 건 스엠바께읎다',
#  '마스크를 써도 예쁜건 가려지지 않는미모',
#  '진짜 완벽하다',
#  '그 제가 잘 몰라서 그러는데 이번이 레벨 마지막 앨범 아니죠 아니 갑자기 이렇게 영상을 많이 올려주길래 좀 불안해서 나 이제야 레벨이 좋아질라하는데',
#  '다시여름아련하고 슬픔',
#  '수고했어요 우리 레드벨벳',
#  '자컨 마지막일거 마냥 만드셨네요 ',
#  '바다가 들려 스페셜 비디오 같고 좋아 빨간맛 활동같아 너무 좋아',
#  '웬디 끝부분이 예술',
#  '아이린 천재 아이돌',
#  '당신들 감동 갬동',
#  '사랑해 레드벨벳',
#  '케익',
#  '수록곡머박',
#  '사랑해',
#  '화장안해도 배주현 왜렇게 이쁜지',
#  '레드벨벳 누나들너무예뻐요',
#  '스엠낯설다너',
#  '케이크 떨어지려 할 때 나도 심장이 쿵쾅거랴유',
#  '이걸로 안무 영상 퉁치는건아니죠 제발요 안무영상 주세요',
#  '영상 보면 찍어둔 영상이레코딩 비하인드 영상 개 더 있는듯 안무 연습 영상안무 연습 비하인드음방 대기실 비하인드뮤비 비하인드 올라온거에 없는 부분 이렇게 같은데 올려줄거지 ',
#  '이제 끝내는구나',
#  '뭐야분 초가 원래 이렇게 빨라',
#  '스엠 왜 갑자기 일해',
#  '얼큰한 김치칼국수 국물이 먹고싶다',
#  '슬기 베이지색 마스크 여기서 처음 보이는건가',
#  '소즁',
#  '대동안아이린',
#  '아이린 벌써 나옴',
#  '왜 년 월일일까',
#  '  아이디어가 떨어졌나요',
#  '아니 난 라가를 사랑해 진심을 다해 사랑해 퀸덤을 사랑해 항상듣고있어 어쩔수없어 내가 제일 좋아하는 노래 퀸덤 레드벨벳',
#  '너무너무 좋앗던 활동이엇어 덕분에 분에 넘칠 만큼 행복했어 정말고맙고 사랑해 글고 스엠 저기있는거 다내놔주세요 이러케일잘하면서 그동안엔왜안햇대',
#  '아니 진짜 무슨일이햐 스엠 일 잘해줘서 너무 감사한데 더 감사좀 부탁드립시다 헐헝 너무 좋자나',
#  '사랑해 승완수영예림주현슬기 ',
#  '슴 왤케 일잘해 따른곡들도 더내줘',
#  '레드벨벳으로 앞으로의 활동 항상응원해 다음컴백 벌써 존버중 ',
#  '아니 잠깐 이렇게 퉁치지 말고 댄프 올려 우리 애들 미모에 홀려 넘어갈뻔했네',
#  '연습복 레벨 개좋아',
#  '안무연습영상 기다릴게요',
#  '이번에 안무영상 있구나 미미미미미핀 제발 빨리 언능 ',
#  '공주님들 겨울에 배드보이 싸이코급 곡들고 오실거죠',
#  '나 울어 ',
#  '제복슬기 더주세요',
#  '다시 여름 애들 연습하는 모습 너무 좋다 이런 좋은 영상 더 많이 올려주세요',
#  '아이린 썸네일 되면 볼게요 하지만 무엇보다 그녀는 최고의 걸그룹 아이돌입니다 재능 순수한 친절 및 동등한 비주얼 우리 모두가 그녀를 롤 모델로 삼아야 하는 것은 당연합니다 아이린 진짜 대단해',
#  '다시 갑질린',
#  '아니 안하던 짓 하니까 뭔 일 일어날까봐 무섭긴 하다 스엠아',
#  '미미미미미핀 스엠 머선일이고 자컨 넘쳐나서 너무행복해',
#  '레드벨벳 영원히 사랑해 ',
#  '세상 행복',
#  '계절을 돌고 시간이 지나 또 만날 걸 아니까 다시 만날 그 날까지 꼭꼭 기다릴게요',
#  '음악 입혀서 퉁치지 말고 리얼리티자컨도 주세요',
#  '퍄 넘 좋다',
#  '나의 여름 레드벨벳 추워지는 계절에 또 만나',
#  '녹음실 레드벨벳 더주세요 ',
#  '스엠 갑자기 열일하네 다시 초심처럼 맘을 잡은건가 그마음이라면 너무 감사합니당 녹음실은 언제봐도 절로 보는게 좋아져 퀸덤 안무연습 너무 잘춘당 브금도 이번활동 돌아보는 느낌에 적합한 곡으로 분위기를 이어가넹 놓칠 뻔한 움까지 울퀸드벨벳 진짜 너무 고생겸 열일 했다아 퀸덤 연습실 안무 풀영상 나오기를 ',
#  '에스엠 왜이래 고마워',
#  '자 너희들이 안무영상 찍은 거 있다고 동네방네 떠들었는데 안무영상 안 내놓기만 해바라',
#  '스엠 무슨 일이야',
#  '열일 무슨일이쥬 어리둥절 어쨌든 죠이 최고  ',
#  '제대로 아련하게 편집 하셧네 딱 이시간에 듣기 좋은 곡이네요',
#  '스페셜 비디오 너무 좋아요 안무영상도 곧 올라오겠죠',
#  '이번 컴백을 수고많았어요 언니들다음 컴백을 기대돼용',
#  '다좋은데 활동기간 한달로늘리고 자컨도 활동 기간때 올려주게요',
#  '자컨이 쏟아지네 행복하다',
#  '  일단 고맙긴한데 안그러다가 갑자기 잘해주니까 경계하는 중 ',
#  '웬디누나 너무 예쁘다',
#  '진짜 귀엽네',
#  '이제 안무연습영상도 줘요',
#  '컨텐츠 영상 계속 있을거라고 믿어요',
#  '진짜 눈물 좍좍 외이레 안 해주던 거 막 해주니까 너무 어색함',
#  '안녕 여름으로 돌고 돌아 다시 여름으로 인사를 건내준만큼 우린 늘 같은 모습으로 뜨겁게 인사를 받으며 건낼게  ',
#  '다시여름 내 눈물버튼임 퀸덤 준비과정 부터 활동까지 쫙 보니까 새삼 이번앨범 너무너무 소중하고고맙고 그렇다 자 이제 안무연습영상 풀캠으로 주시면 완벽해여 슴',
#  '진짜 에스엠이 뭘 올려주다니 감동적이다',
#  '아니 레벨 자컨팀 내가 많이 사랑해요 우리 레드벨벳 최강 레벨팀 언제나 사랑하고 우리 오래봐요',
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       손끝이 시리더니 벌써 봄이 왔네꿈같은 바람이 불어 곳곳에여느 때 와는 다른 듯한 이 기분이 반가워내일은 좀 다른 날이 되려나어둠의 그림자 깊은 이 밤에 남겨진달이 달이 밝아와빛을 그리고 있어내 몸에서 널 뺀 만큼욕조에 물이 미련이 되어 넘쳐흘러한숨이 가득 그 공간을 채워새벽이 찾아오면혼자 남겨질 때면    별이 빛나는 밤네가 휘휘휘 불어와너와 나 나눈 수많은 밤나를 취하게 만들어별이 빛나는 밤야야야야이야별이 빛나는 밤야야야야야야야 별이 빛나는 밤겨울이 지나고 또다시 꽃은 피고따뜻한 공기 냄새가 날 감싸달라진 거 없는 똑같은 일상이 반복돼그래도 내일을 기다려봐하루에 끝에서 이 자리에 남아서날이 날이 새도록너를 그리고 있어            난 그 자리 그대로까만 밤하늘에 가려잠시 보이지 않는 거야새벽이 찾아오면혼자 남겨질 때면    별이 빛나는 밤네가 휘휘휘 불어와너와 나 나눈 수많은 밤나를 취하게 만들어별이 빛나는 밤야야야야이야별이 빛나는 밤야야야야야야야 별이 빛나는 밤      네가 없는 밤가슴이 공허해우리의 풍경이 저물어가현실을 부정해 눈을 감아도네가 보여 왜 아른거려     무너져 가네    별이 빛나는 밤네가 휘휘휘 불어와너와 나 나눈 수많은 밤나를 취하게 만들어별이 빛나는 밤야야야야이야별이 빛나는 밤야야야야야야이야별이 빛나는 밤이 노래의 세계가 화사라는 걸 확실히 알아      ',
#  '신승균    이란게 나이들어서 그렇다는게 아니고 다른 걸그룹과는 다르게 성숙미나 웅장함 음악적재능 등이 보이니까 그렇게 부르는 겁니다 너무 일차원적으로만 해석하시네요',
#  '아니 별이 빛나는 밤은 뮤비가 진짜 너무 예쁨 자연경관이랑 멤버들이랑 찰떡으로 잘 어울림 진짜 장면 하나하나가 다 레전드 ',
#  '  살고 싶은 나의 욕망   보컬 여신 춤의 여신  는 당신이들을 수있는 최고이며 결국 당신에게 일어날 수있는 일들    ',
#  '머지다',
#  '진짜 헤어스타일이며 분위기며 찰떡 인생곡 진짜',
#  '고인데 중때 추억이 담긴 곡 곡빅뱅 꽃길마마무 별이빛나는밤레드벨벳 배드보이이거 개가 우리학교 급식시간에 맨날 틀어줬었는데 항상 들을때마다 추억돋음',
#  ...]

# %%
"""# soynlp를 이용한 토크나이즈 만들기

"""

# SOYNLP 다운로드
# !pip install soynlp
# Out:
# Requirement already satisfied: soynlp in /usr/local/lib/python3.7/dist-packages (0.0.493)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from soynlp) (1.4.1)
# Requirement already satisfied: numpy>=1.12.1 in /usr/local/lib/python3.7/dist-packages (from soynlp) (1.19.5)
# Requirement already satisfied: psutil>=5.0.1 in /usr/local/lib/python3.7/dist-packages (from soynlp) (5.4.8)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from soynlp) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->soynlp) (1.0.1)

# %%
import urllib.request
from soynlp.utils import DoublespaceLineCorpus
from soynlp.noun import LRNounExtractor_v2
from soynlp.word import WordExtractor
from soynlp.tokenizer import LTokenizer

# %%
noun_extractor = LRNounExtractor_v2(verbose=True)
nouns = noun_extractor.train_extract(kr)
nouns

# %%
list(noun_extractor._compounds_components.items())[:5]
# Out:
# [('아아아아아아아아아아', ('아아아아아아', '아아아아')),
#  ('모르겠다라이브가미', ('모르겠다', '라이브', '가미')),
#  ('너무너무너무너무너무', ('너무', '너무', '너무', '너무', '너무')),
#  ('너무아름다운다운', ('너무', '아름', '다운', '다운')),
#  ('리얼재연사계한사계후', ('리얼', '재연', '사계한', '사계후'))]

# %%
noun_extractor.lrgraph.get_r('샤이니', topk=20)
# Out:
# [('', 327),
#  ('는', 48),
#  ('가', 36),
#  ('편', 20),
#  ('의', 17),
#  ('를', 10),
#  ('랑', 10),
#  ('도', 8),
#  ('와', 6),
#  ('스러움이', 6),
#  ('에', 6),
#  ('스러움의', 6),
#  ('스러운', 5),
#  ('만', 5),
#  ('스러움', 3),
#  ('편은', 3),
#  ('편이', 3),
#  ('즈백', 2),
#  ('한테', 2),
#  ('에게', 2)]

# %% [markdown]
# # Word Extraction

# %% [markdown]
# 품사 판별 (Part of speech tagging)은 주어진 문장에 대하여 단어를 인식하고 각 단어의 품사를 판별하는 과정입니다. KoNLPy는 여러 종류의 품사 판별기를 파이썬 환경에서 이용할 수 있도록 도와줍니다.
#
# 품사 판별기는 주로 말뭉치라 불리는 학습데이터를 기반으로 문장/어절의 패턴을 학습합니다.
#
# [('아이오아이', '명사'), ('가', '조사'), ('5', '숫자'), ('년', '명사'), ...]
#
# 위와 같이 단어 별로 품사가 적혀있는 데이터를 학습에 이용합니다. 이와 같이 학습용 데이터를 이용하는 방법을 supervised learning이라 합니다. 하지만, supervised learning 기반 품사 판별기가 가지는 위험 중 하나는 모르는 단어가 등장했을 때 이를 처리하는 방법입니다. '아이오아이' 분명 단어임에도 학습 때 본 적이 없다면 단어로 인식되지 않을 수 있습니다.
#
# 또 다른 위험 중 하나는 도메인의 특별한 어구들을 알 수 없다는 겁니다. '끝까지간다'는 배우 이선균이 출연한 영화 제목 입니다. 데이터 분석의 입장에서는 '끝까지간다'를 문장이 아닌 단어로 보는 것이 더 적합합니다. 만약 영화리뷰를 분석하고 있다면 '끝까지간다'라는 단어가 여러 번 등장할 것이고, 우리는 리뷰들에 있는 이 단어에 여러번 노출되어 단어로 인식할 것입니다. 하지만 품사 판별기의 목적은 주어진 문장/어절을 알고 있는 단어들로 분해하여 인식하는 것이기 때문에 이를 하나의 단어로 인식하지 않습니다. 목적이 다르죠.

# %% [markdown]
# 그래서 주어진 문서 집합에서 패턴을 찾아내어 단어를 추출해보려 합니다. 다른 학습데이터는 이용하지 않으며, 통계에 기반하여 단어를 찾아내는 unsupervised learning 방법입니다. 통계 기반으로 단어를 추출하는 방법은 여러가지가 있습니다. 그 중 3가지 방법을 구현해 두었습니다.

# %%
# Word Extraction

word_extractor = WordExtractor(min_frequency=5,
    min_cohesion_forward=0.05, 
    min_right_branching_entropy=0.001
)
word_extractor.train(kr) # list of str or like
words = word_extractor.extract()
len(words)
# Out:
# training was done. used memory 0.754 Gb
# all cohesion probabilities was computed. # words = 15588
# all branching entropies was computed # words = 20586
# all accessor variety was computed # words = 20586
# 3112

# %%
words['샤이니']
# Out:
# Scores(cohesion_forward=0.9398979049603626, cohesion_backward=0.08642716314028859, left_branching_entropy=3.8782821893880173, right_branching_entropy=3.9239078986883, left_accessor_variety=73, right_accessor_variety=82, leftside_frequency=591, rightside_frequency=16)

# %% [markdown]
# WordExtractor가 계산하는 것은 다양한 종류의 단어 가능 점수들입니다. 이를 잘 조합하여 원하는 점수를 만들 수도 있습니다. 즐겨쓰는 방법 중 하나는 cohesion_forward에 right_branching_entropy를 곱하는 것으로, (1) 주어진 글자가 유기적으로 연결되어 함께 자주 나타나고, (2) 그 단어의 우측에 다양한 조사, 어미, 혹은 다른 단어가 등장하여 단어의 우측의 branching entropy가 높다는 의미입니다.

# %%
import math

def word_score(score):
    return (score.cohesion_forward * math.exp(score.right_branching_entropy))

print('단어   (빈도수, cohesion, branching entropy)\n')
for word, score in sorted(words.items(), key=lambda x:word_score(x[1]), reverse=True)[:30]:
    print('%s     (%d, %.3f, %.3f)' % (
            word, 
            score.leftside_frequency, 
            score.cohesion_forward,
            score.right_branching_entropy
            )
         )
# Out:
# 단어   (빈도수, cohesion, branching entropy)
#
# 진짜     (3226, 0.866, 4.862)
# 합니다     (44, 0.681, 4.451)
# 노래     (2637, 0.886, 4.074)
# 샤이니     (591, 0.940, 3.924)
# 근데     (395, 0.914, 3.742)
# 까지     (34, 0.382, 4.505)
# 뮤비     (669, 0.893, 3.487)
# 너무     (2778, 0.905, 3.466)
# 감사합니다     (267, 0.733, 3.657)
# 항상     (200, 0.948, 3.382)
# 계속     (432, 0.719, 3.654)
# 내가     (494, 0.479, 4.035)
# 투피엠     (286, 0.834, 3.429)
# 역시     (259, 0.583, 3.755)
# 영상     (456, 0.579, 3.644)
# 댓글     (461, 0.907, 3.171)
# 정말     (464, 0.443, 3.887)
# 머리     (233, 0.685, 3.445)
# 우리집     (671, 0.597, 3.565)
# 했는데     (106, 0.537, 3.662)
# 뭔가     (218, 0.701, 3.395)
# 앨범     (188, 0.917, 3.123)
# 많이     (412, 0.463, 3.768)
# 으로     (18, 0.159, 4.804)
# 목소리     (307, 0.896, 3.016)
# 이렇게     (451, 0.284, 4.139)
# 준호     (420, 0.534, 3.478)
# 사랑해     (604, 0.524, 3.496)
# 입니다     (70, 0.375, 3.808)
# 컴백     (425, 0.728, 3.138)

# %% [markdown]
# Cohesion score, Branching Entropy, Accessor Variety 에 대하여 각각의 점수만 이용하고 싶은 경우에는 다음의 함수를 이용합니다.

# %%
cohesion_scores = word_extractor.all_cohesion_scores()
cohesion_scores['샤이니'] # (cohesion_forward, cohesion_backward)
# Out:
# all cohesion probabilities was computed. # words = 15588
# (0.9398979049603626, 0.08642716314028859)

# %%
branching_entropy = word_extractor.all_branching_entropy()
branching_entropy['샤이니'] # (left_branching_entropy, right_branching_entropy)
# Out:
# all branching entropies was computed # words = 20586
# (3.8782821893880173, 3.9239078986883)

# %%
accessor_variety = word_extractor.all_accessor_variety()
accessor_variety['샤이니'] # (left_accessor_variety, right_accessor_variety)
# Out:
# all accessor variety was computed # words = 20586
# (73, 82)

# %%
# # 예제 말뭉치 다운로드
# urllib.request.urlretrieve("https://raw.githubusercontent.com/lovit/soynlp/master/tutorials/2016-10-20.txt", filename="2016-10-20.txt")
# corpus = DoublespaceLineCorpus("2016-10-20.txt")
# len(corpus)

# # 예제 말뭉치 상위 5개 문서 텍스트 확인
# i = 0
# for document in corpus:
#   if len(document) > 0:
#     print(document)
#     i = i+1
#   if i == 5:
#     break
# Out:
# 30091

# %%
# # 예제 말뭉치 테스트
# word_extractor = WordExtractor()
# word_extractor.train(kr)
# word_score_table = word_extractor.extract()
# word_score_table["샤이"].cohesion_forward
# Out:
# training was done. used memory 0.767 Gb
# all cohesion probabilities was computed. # words = 15588
# all branching entropies was computed # words = 20586
# all accessor variety was computed # words = 20586
# 0.8878923766816144

# %%
# # 단어 워드클라우드 시각화 (불용어 제거 단어 선정을 위한)
# from wordcloud import WordCloud
# default_path = '/content/drive/MyDrive/[공유] Mulcam_Army 공유폴더!/'
# cloud = WordCloud(font_path=default_path+'NanumGothic.ttf').generate(corpus)
# plt.figure(figsize=(20,15))
# plt.imshow(cloud)
# plt.axis('off')

# %%
# 단어 토크나이징
noun_extractor = LRNounExtractor_v2(verbose=True)

# 말뭉치는 리스트값으로 입력(명사만 추출)
nouns = noun_extractor.train_extract(kr)

word_extractor = WordExtractor(min_frequency=5,
                               min_cohesion_forward=0.05,
                               min_right_branching_entropy=0.001)
word_extractor.train(kr)
# Out:
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=3929, neg=2321, common=107
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 67218 from 21738 sents. mem=0.732 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. #eojeols=197809, mem=0.732 Gb
# [Noun Extractor] batch prediction was completed for 18933 words
# [Noun Extractor] checked compounds. discovered 5433 compounds
# [Noun Extractor] postprocessing detaching_features : 10340 -> 8745
# [Noun Extractor] postprocessing ignore_features : 8745 -> 8611
# [Noun Extractor] postprocessing ignore_NJ : 8611 -> 8478
# [Noun Extractor] 8478 nouns (5433 compounds) with min frequency=1
# [Noun Extractor] flushing was done. mem=0.752 Gb
# [Noun Extractor] 55.78 % eojeols are covered
# training was done. used memory 0.775 Gb

# %%
# 명사, 단어 확률값만 활용하여 토크나이저 만들기
cohesion_score = {word:score.cohesion_forward for word, score in words.items()}

noun_scores = {noun:score.score for noun, score in nouns.items()}
combined_scores = {noun:score + cohesion_score.get(noun, 0)
    for noun, score in noun_scores.items()}
combined_scores.update(
    {subword:cohesion for subword, cohesion in cohesion_score.items()
    if not (subword in combined_scores)}
)

tokenizer = LTokenizer(scores=combined_scores)

print(kr[0])
print(tokenizer.tokenize(kr[0]))
# Out:
# 와 진짜 목소리 대박인데근데 양손은 서로 가위바위보하는 건가요
# ['와', '진짜', '목소리', '대박', '인데근데', '양손', '은', '서로', '가위바위보', '하는', '건가', '요']

# %%
"""# 빈도수 계산을 위한 텍스트 데이터 벡터화
 - BoW 단어를 특성 벡터로 변환
 - TF-IDF 를 사용하여 단어 적합성 평가
"""

# BoW 모델로 벡터화
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(tokenizer=tokenizer,
                        ngram_range=(3,6),
                        max_df = .1,
                        max_features=5000)
docs = kr
bag = count.fit_transform(docs)

# %%
# TF_IDF 벡터화
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(ngram_range=(3,6), # 유니그램 바이그램으로 사용
                        min_df = 3, # 3회 미만으로 등장하는 토큰은 무시
                        max_df =0.95, # 많이 등장한 단어 5%의 토큰도 무시
                        tokenizer = tokenizer,
                        token_pattern = None)
tfidf.fit(docs)
docs_soynlp = tfidf.transform(docs)

# %%
"""# 잠재 디리클레 할당을 사용한 토픽 모델링"""

# LDA 사용 (BoW 기반)
from sklearn.decomposition import LatentDirichletAllocation
lda = LatentDirichletAllocation(n_components = 10,
                                random_state = 1,
                                learning_method = 'batch')

X_topics = lda.fit_transform(bag)

# %%
# 결과 분석을 위해 각 토픽 당 중요 단어 10개 출력 (BoW 기반)
n_top_word = 10
feature_name = count.get_feature_names()
for topic_idx, topic in enumerate(lda.components_):
  print("토픽 %d:" % (topic_idx+1))
  print([feature_name[i] for i in topic.argsort()[:-n_top_word - 1: -1]])
# Out:
# 토픽 1:
# ['하루 에 한번씩', '좋다 고 생각', '수트 절대 반대', '합니다 감사 합니다', '우리 집 조회수', '감사 합니다 감사', '아이 유 팔레트', '근데 화는 왜', '잘 몰라 서', '언니 들 너무']
# 토픽 2:
# ['이 노래 는', '도시락 속 치킨', '내가 좋아 하는', '아이 와 나의 바다', '와 나의 바다', '아이 와 나의', '지금 들어 도', '너무 사랑 해', '맘은 덤더럼 덤덤', '우리 집 재컴백']
# 토픽 3:
# ['만뷰 만뷰 만뷰', '만뷰 만뷰 만뷰 만뷰', '만뷰 만뷰 만뷰 만뷰 만뷰', '만뷰 만뷰 만뷰 만뷰 만뷰 만뷰', '우리 집으로 가자', '아무 도 모르', '아랍어 번역 을', '우리 집으로 가자 우리 집으로', '우리 집으로 가자 우리', '집으로 가자 우리']
# 토픽 4:
# ['아 진짜 요', '일 월 일', '월 일 월', '월 일 월 일', '노래 너무 좋다', '일 월 일 월', '일 월 일 월 일', '월 일 월 일 월', '월 일 월 일 월 일', '우리 집 뮤비']
# 토픽 5:
# ['너무 좋아 서', '우리 집 준호', '노래 가 너무', '이 아니 라', '가슴 이 웅장', '가 너무 좋아', '에 진심 인', '악뮤 아이 유', '노래 너무 좋아', '이 웅장 해진다']
# 토픽 6:
# ['너무 좋아 요', '이 노래 가', '노래 너무 좋아', '진짜 너무 좋다', '진짜 너무 좋아', '출석 출석 출석', '화려 하지 않은', '하지 않은 고백', '화려 하지 않은 고백', '노래 너무 좋아 요']
# 토픽 7:
# ['눈 딱 감고', '딱 감고 낙하', '눈 딱 감고 낙하', '숨 딱 참고', '날 눈 딱', '셋 숨 딱', '둘 셋 숨', '둘 셋 숨 딱', '셋 하면 뛰어', '숨 딱 참고 낙하']
# 토픽 8:
# ['마음 에 들어', '주위 로 모여', '사람 은 못', '따러 나 받으면 못 멈춰', '따러 나 받으면 못 멈춰 대형', '대형 전부 무시', '대로 스텝 밟아 자 누가 제일', '대로 스텝 밟아 자 누가', '대로 스텝 밟아 자', '가는 대로 스텝 밟아 자 누가']
# 토픽 9:
# ['자윤아 언니 왔다', '왔다 자윤아 언니 왔다', '왔다 자윤아 언니', '자윤아 언니 왔다 자윤아', '자윤아 언니 왔다 자윤아 언니 왔다', '언니 왔다 자윤아', '언니 왔다 자윤아 언니', '언니 왔다 자윤아 언니 왔다', '자윤아 언니 왔다 자윤아 언니', '왔다 자윤아 언니 왔다 자윤아']
# 토픽 10:
# ['별이 빛나는 밤', '한 번 더', '그러니 한 번', '노래 가 좋아', '나 나눈 수많은 밤나를 취하게', '수많은 밤나를 취하게 만들어 별이 빛나는', '만들어 별이 빛나는', '취하게 만들어 별이 빛나는', '취하게 만들어 별이', '빛나는 밤네가 휘휘 휘 불어']

# %%
# LDA 사용 (tf-idf 기반)

lda_tfidf = LatentDirichletAllocation(n_components = 10,
                                      random_state = 1,
                                      learning_method = 'batch')

X_topics = lda_tfidf.fit_transform(docs_soynlp)

# %%
# 결과 분석을 위해 각 토픽 당 중요 단어 10개 출력 (tf-idf 기반)
n_top_word = 10
feature_name = count.get_feature_names()
for topic_idx, topic in enumerate(lda_tfidf.components_):
  print("토픽 %d:" % (topic_idx+1))
  print([feature_name[i] for i in topic.argsort()[:-n_top_word - 1: -1]])
# Out:
# 토픽 1:
# ['내버려두지 않을 거라고 죄다 낭떠러지 야', '너무 재밌어 요', '야야야야 이야 별이 빛나는 밤야야야야', '오면혼자 남겨 질 때면', '너무 좋고 뮤비', '야야야야야야 야 별이 빛나는', '지지 지 동그라미 주위 로', '너무 좋다 이런', '내일은 좀 다른 날이 되려나', '빛나는 밤 네가 없는']
# 토픽 2:
# ['와 진짜 대박 이다', '셋 하면 뛰어 낙하 하핫 둘', '니 맘을 숨기지마', '준케이 랑 닉쿤 이 브이앱 에서', '니 맘을 숨기지마 우리', '좀 다른 날이 되려나', '우리 가 따르는 아랍어 번역 이없는', '니 맘을 숨기지마 우리 집으로', '좀 다른 날이 되려나 어둠', '내일은 좀 다른 날이 되려나 어둠']
# 토픽 3:
# ['애들 은 다 비켜라 비켜동그라미', '너와 헤매고 싶어 니 눈빛', '거야 새벽 이 찾아 오면', '이유는 아랍어 번역 을 다운로드하십시오 우리', '야야야야 이야별이 빛나는 밤', '깊이 알고 싶어 그 아주', '진짜 너무 좋고', '은 못 껴음악은', '우리 가 따르는 아랍어 번역', '내 맘은 덤더럼']
# 토픽 4:
# ['대초반전이분명한데도중년의여성들을능가하는맵씨와행동걸음걸이그래도처녀티도엿보이는어느여자가그초로의신사와비밀리에만나그를본눈은그동네에서정여사등동년또래 몇살차이여자들은그걸본대로까지짐작큰일낼내용도포함정여사가언젠가그노인이김여사가말하던그여자아닌여자와함께차를같이타고가다가 마침은행앞에서정차하여내리는것을봤어생략 그노인인신사는그런또래여성을한두명만나는것이아니었다서로에게자신은일가친척그리고마누라인처와자식들이여간못마땅하다고모모텔에서들은여자가여러통로로정여사귀에까지들어갔다작가말련은말한다젊은여자들이꾸미던예비음모가미혼이나기혼중에도젊은미를내세워노인갑부를상대로연애하지만절대집한채물려받을수있는재력가노인도있으나전혀인헛물켜는 집한채요네아빠욤', '노래 너무 좋음', '내 빵쪼가리 완전', '않겠다고 죄다 낭떠러지 야', '내 손을 잡으면 하늘을 나는', '신나 쪄 우리 형 신나', '거 보니까 내가', '너무 귀엽 잖아', '뮤비 보다 이게 더', '너무 예쁘 고']
# 토픽 5:
# ['지어 함께 깨트려', '너무 좋아 서', '날 따라와 이 시끄러운', '대로 스텝 밟아 자 누가 제일', '내 눈을 본다 면밤하늘의 별이 되는', '너무 좋아 김세정', '땡기러 흔쾌히 따러 나 받으면 못', '이걸 보고 있는', '날 여기 로 이끌었어요썸네일이 날 여기', '그렇 구나 드르륵 탁 아']
# 토픽 6:
# ['오늘 도 출첵', '아닌 척 하는 게좀', '노래 는 다', '주년 기념 만뷰 우', '진짜 요네 진짜 요하루', '주하나님이신추밀박하영시호주님이신아빠츄이신아빠빠빠빠빠 생활 처소체류현재지태전동태전길 번지 명광주택동번지건축물또한시호주님소유건축물로 떠꺼리', '진짜 요네 진짜 요하루 종일', '아름 다운 노래', '려봐 하루 에 끝에서', '노래 는 정말']
# 토픽 7:
# ['사람들 의 마음', '요 개 돌파 감사 합니다 좋아', '일 월 일', '너무 귀여 웤', '별이 빛나는 밤 야야야야 이야별이 빛나는', '너와 헤매고 싶어', '제 채널 에 합', '시선 이 분산', '우리 집으로 가자 단 아무', '개인적 인 생각']
# 토픽 8:
# ['오늘 하루 만 살기', '이유는 아랍어 번역 을 다운로드하십시오 아랍어', '가 어디 라고', '너무 세련 되고', '질 때면 별이 빛나는 밤네가', '꼬북좌 단발 좌', '가사 가 너무', '뺀 만큼욕조에 물이 미련 이 되어', '사람 은내가 가진 무엇 을 사랑', '완벽 한 걸그룹']
# 토픽 9:
# ['생명유지호흡맥박작동하처형처리 살려 가며란말은무엇을의미하는지를찰라이해실천형집행형벌단계처리해라 째목아지에서귀태들 진정 작위범들', '거 말고 요날', '사람 은내가 가진 무엇', '내일은 좀 다른 날이', '야 사랑 해', '일 월 일 월', '무대 삼아 누비지 무리', '시작 인데 그만 노심초사해 밀착 해', '낙하 하핫 둘', '맘은 덤더럼 덤덤 봐봐봐봐 내']
# 토픽 10:
# ['내버려두지 않을 거라고 죄다', '내 반쪼가리 완전', '노래 가 너무', '을 느낄 수 있을 거야 셋', '시작 할 때', '조회수 가 만', '아 진짜 요 네 진짜 요', '살기 로 한', '야야야 별이 빛나는', '시호주님 창조 주하나님이신추밀박하영시호주님이신아빠츄이신아빠빠빠빠빠 생활']
